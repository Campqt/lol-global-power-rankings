# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO
import pandas as pd
import numpy as np

# %%
S3_BUCKET_URL = "https://power-rankings-dataset-gprhack.s3.us-west-2.amazonaws.com"


def download_gzip_and_write_to_json(file_name):
   # If file already exists locally do not re-download game
   if os.path.isfile(f"{file_name}.json"):
       return

   response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
   if response.status_code == 200:
       try:
           gzip_bytes = BytesIO(response.content)
           with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
               with open(f"{file_name}.json", 'wb') as output_file:
                   shutil.copyfileobj(gzipped_file, output_file)
               print(f"{file_name}.json written")
       except Exception as e:
           print("Error:", e)
   else:
       print(f"Failed to download {file_name}")


def download_esports_files():
   directory = "esports-data"
   if not os.path.exists(directory):
       os.makedirs(directory)

   esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data","tournaments_without_game_data","unfiltered_players","unfiltered_teams"]
   for file_name in esports_data_files:
       download_gzip_and_write_to_json(f"{directory}/{file_name}")





if __name__ == "__main__":
    download_esports_files()
# Out:
# esports-data/tournaments_without_game_data.json written
# esports-data/unfiltered_players.json written
# esports-data/unfiltered_teams.json written

# %% [markdown]
# First issue the read_json of pandas cutted ids because the number were too long

# %%
def json_to_df(path):
    with open(path, 'r') as j:
        contents = json.loads(j.read())

    df = pd.json_normalize(contents)
    return df

# %%
tournaments = json_to_df('esports-data/tournaments.json')
tournaments2 = json_to_df('esports-data/tournaments_without_game_data.json')
players = json_to_df('esports-data/unfiltered_players.json')
#unfiltered_players = json_to_df('esports-data/unfiltered_players.json')
leagues = json_to_df('esports-data/leagues.json')
teams = json_to_df('esports-data/unfiltered_teams.json')
mapping_data = json_to_df('esports-data/mapping_data.json')
new_leagues = pd.read_csv('new_leagues.csv')
new_leagues = new_leagues.drop('Unnamed: 0', axis = 1)
tournaments = pd.concat([tournaments, tournaments2], ignore_index=True)
tournaments.sort_values(by =['startDate'], inplace =True)
players = players.drop_duplicates(subset=['player_id'])

# %%
new_leagues
# Out:
#                     id                              slug   ELO
# 0    98767991299243165                               lcs  1300
# 1   109511549831443335  north_american_challenger_league  1100
# 2   109518549825754242        lcs_challengers_qualifiers  1000
# 3   107898214974993351              college_championship  1000
# 4    98767991332355509                      cblol-brazil  1100
# 5    98767991310872058                               lck  1500
# 6    98767991355908944                               lcl  1100
# 7   105709090213554609                               lco  1100
# 8    98767991302996019                               lec  1400
# 9    98767991349978712                         ljl-japan  1100
# 10  101382741235120470                               lla  1100
# 11   98767991314006698                               lpl  1600
# 12  104366947889790212                               pcs  1200
# 13   98767991343597634          turkiye-sampiyonluk-ligi  1000
# 14  107213827295848783                               vcs  1100
# 15   98767991325878492                               msi  1700
# 16   98767975604431411                            worlds  1700
# 17  100695891328981122                      emea_masters  1100
# 18  105266103462388553                               lfl  1100
# 19  105266098308571975                               nlc  1100
# 20  107407335299756365                      elite_series  1000
# 21  105266101075764040                   liga_portuguesa  1000
# 22  105266094998946936                      pg_nationals  1000
# 23  105266088231437431                         ultraliga  1100
# 24  105266074488398661                         superliga  1100
# 25  105266091639104326                       primeleague  1100
# 26  105266106309666619                  hitpoint_masters  1000
# 27  105266111679554379             esports_balkan_league  1000
# 28  105266108767593290                     greek_legends  1000
# 29  109545772895506419                    arabian_league  1000
# 30  108203770023880322                       lck_academy  1000
# 31  106827757669296909                       ljl_academy   900
# 32   98767991335774713            lck_challengers_league  1200
# 33  105549980953490846                     cblol_academy   900
# 34  110371976858004491             north_regional_league   900
# 35  110372322609949919             south_regional_league   900

# %%
mapping_data.head()
# Out:
#         esportsGameId         platformGameId     teamMapping.200  \
# 0  110378429158160389  ESPORTSTMNT01:3416295  105550026570060790
# 1  110471139171602607  ESPORTSTMNT02:3228341  105550005698683818
# 2  110535609417029691  ESPORTSTMNT04:2693199  108352305932141947
# 3  110847390580148354  ESPORTSTMNT01:3413275   99566406332987990
# 4  110413246204026226  ESPORTSTMNT01:3412587  105550001032913831
#
#       teamMapping.100 participantMapping.3 participantMapping.5  \
# 0  105550033967461806   107492116585043595   105388980252039870
# 1  109485335453835911   107560281476330464   107559633217576287
# 2  109696092218588987   105536902415377888   109696579630268337
# 3  107700204561086446    98767991808793901   109642948838393879
# 4  109485335453835911   107560281476330464   107559633217576287
#
#   participantMapping.10 participantMapping.2 participantMapping.1  \
# 0    110730240651882119   108366332471078988   108205130568869560
# 1    105397238669368241   103478281341350420   103478281338008082
# 2    107564428297402857    99566406317824602   109696535754261145
# 3    101383792831678607    99566406443271739    99566406483827119
# 4    103743593842085398   103478281341350420   103478281338008082
#
#   participantMapping.9 participantMapping.7 participantMapping.8  \
# 0   106267600924403194   106267599829820917   107492063150003806
# 1   109519061710277829   109519057410044019   103461966873003900
# 2   105548605376090785   105548731617719496   103963733877026827
# 3    99566406296347493   104668539132702977   105709404500072628
# 4   108395451349202875   110434822594728434   103980682928812378
#
#   participantMapping.6 participantMapping.4
# 0   105501816646382923   102483272156027229
# 1   105397207118950800   101383793082615993
# 2   109705412728201213   109696576870241602
# 3   100160799381721105   107705431471339985
# 4   107559597273805278   101383793082615993

# %%
mask = tournaments['startDate'].str.startswith('2023')
tournaments[mask]
# Out:
#                      id            leagueId                        name  \
# 352  109761195185432372  108001239847565215                  SuperBrawl
# 376  109505898644288466  109505812702106261         Season 2023 Kickoff
# 25   109659890853124371  107581050201097472                Opening 2023
# 38   109672646548487788  107603541524308819                Opening 2023
# 255  109669600527985422   98767991314006698                 Spring 2023
# 94   109660182592761313  107581669166925444                Opening 2023
# 99   109539822190865259  105266088231437431                 Spring 2023
# 13   109625523800645158   98767991335774713                 Spring 2023
# 41   109467209705050129  105266098308571975                 Spring 2023
# 52   109467087406180264  105266074488398661                 Spring 2023
# 86   109699002331645512  107582580502415838                Opening 2023
# 179  109675742494668850  107727703271743942                Opening 2023
# 137  109625152894842837   98767991310872058                 Spring 2023
# 116  109467188125028146   98767991343597634                 Spring 2023
# 188  109698048962321665  107582133359724496                Opening 2023
# 189  109539770333903339  105266091639104326                 Spring 2023
# 60   109467129925344897  105266103462388553                 Spring 2023
# 180  109466537705744120   98767991302996019                 Winter 2023
# 171  109518697660746274  109511549831443335                 Spring 2023
# 112  109518742310926152  109518549825754242              #1 Spring 2023
# 136  109675619694467439  105709090213554609                Split 1 2023
# 104  109676354718284035  107598951349015984                Opening 2023
# 219  109523641416750631   98767991332355509                Split 1 2023
# 209  109672513958565698  101382741235120470                Opening 2023
# 26   109467335886224883  107407335299756365                 Spring 2023
# 190  109467311739792322  105266108767593290                 Spring 2023
# 96   109467260897553204  105266111679554379                 Spring 2023
# 170  109523665497010762  105549980953490846                Split 1 2023
# 80   109467357559212289  105266106309666619                 Spring 2023
# 161  109467367966036144  105266101075764040                 Spring 2023
# 230  109545777182748074  109545772895506419                 Spring 2023
# 187  109517090066605615   98767991299243165                 Spring 2023
# 210  109539799647393670  105266094998946936                 Spring 2023
# 93   109710208772220245   98767991349978712                 Spring 2023
# 59   109704924270305512  104366947889790212                 Spring 2023
# 24   109749565997987636  107213827295848783                 Spring 2023
# 85   109919226376366902   98767991302996019                 Spring 2023
# 185  109974742840567627  109518549825754242              #2 Spring 2023
# 207  110017385374098523  104366947889790212      Playoffs - Spring 2023
# 150  110016413865287161  100695891328981122      Play Ins - Spring 2023
# 51   110016463793610620  100695891328981122    Main Stage - Spring 2023
# 166  110138704782649096  109518549825754242       Promotion Spring 2023
# 134  110198981276611770   98767991325878492                    MSI 2023
# 165  110372140231846916  110371976858004491                Closing 2023
# 4    110310652404523974  105266088231437431                 Summer 2023
# 3    110349992504762921  105266074488398661                 Summer 2023
# 22   110428848766564346   98767991314006698                 Summer 2023
# 76   110424922266960422  105266103462388553                 Summer 2023
# 84   110343648526792583  105266091639104326                 Summer 2023
# 11   110372454557117766  110372322609949919                Closing 2023
# 132  110303581083678395   98767991299243165                 Summer 2023
# 148  110378429156980338   98767991335774713                 Summer 2023
# 12   110425027634430773  105266101075764040                 Summer 2023
# 169  110444842958969834  105266106309666619                 Summer 2023
# 1    110428723804419399  105266108767593290                 Summer 2023
# 7    110425082378454783  105266098308571975                 Summer 2023
# 48   110411420269584926  101382741235120470                Closing 2023
# 2    110424377524465827  107407335299756365                 Summer 2023
# 131  109675608880518030  105709090213554609                 Summer 2023
# 10   110418013822985087  105266111679554379                 Summer 2023
# 6    110429898578299667   98767991343597634                 Summer 2023
# 149  110371551277508787   98767991310872058                 Summer 2023
# 9    110444946767792846  105266094998946936                 Summer 2023
# 69   110574243270525539  109511549831443335                 Summer 2023
# 135  110395308894756789   98767991349978712                 Summer 2023
# 130  110413046183015975   98767991332355509          CBLOL 2023 Split 2
# 37   110413232002702589  105549980953490846  CBLOL Academy 2023 Split 2
# 147  110422923164198764  109545772895506419                 Summer 2023
# 75   110428603624764603  109518549825754242              #1 Summer 2023
# 133  110429332688604205   98767991302996019                 Summer 2023
# 8    110507407705819578  106827757669296909                        2023
# 23   110416959491275651  107213827295848783                 Summer 2023
# 168  110423696147088301  104366947889790212                 Summer 2023
# 0    110733838935136200  109518549825754242              #2 Summer 2023
# 5    110825936250664572   98767991314006698        Regional Finals 2023
# 129  110847340080101648  104366947889790212      Playoffs - Summer 2023
# 128  110535609415063567  100695891328981122                 Summer 2023
# 167  110848560874526298   98767991302996019          Season Finals 2023
# 267  110909366079472439   98767991310872058        Regional Finals 2023
# 290  110894544221659776  109518549825754242       Promotion Summer 2023
# 347  110988896196596544  110988878756156222                        2023
#
#                                   slug sport   startDate     endDate  \
# 352                    tft_events_2023   lol  2023-01-01  2023-12-30
# 376                season_2023_kickoff   lol  2023-01-08  2023-01-13
# 25                    ddh_opening_2023   lol  2023-01-11  2023-04-15
# 38          golden_league_opening_2023   lol  2023-01-12  2023-03-30
# 255                    lpl_spring_2023   lol  2023-01-12  2023-04-16
# 94                     el_opening_2023   lol  2023-01-12  2023-03-28
# 99               ultraliga_spring_2023   lol  2023-01-14  2023-04-04
# 13         lck_challengers_spring_2023   lol  2023-01-14  2023-04-10
# 41                     nlc_spring_2023   lol  2023-01-15  2023-03-31
# 52               superliga_spring_2023   lol  2023-01-15  2023-04-03
# 86           stars_league_opening_2023   lol  2023-01-16  2023-04-08
# 179           liga_master_opening_2023   lol  2023-01-16  2023-04-08
# 137                    lck_spring_2023   lol  2023-01-16  2023-04-12
# 116                    tcl_spring_2023   lol  2023-01-17  2023-04-02
# 188                   vdl_opening_2023   lol  2023-01-17  2023-04-08
# 189           prime_league_spring_2023   lol  2023-01-17  2023-04-04
# 60                     lfl_spring_2023   lol  2023-01-17  2023-04-01
# 180                    lec_winter_2023   lol  2023-01-19  2023-02-28
# 171                   nacl_spring_2023   lol  2023-01-19  2023-04-03
# 112      nacl_qualifiers_1_spring_2023   lol  2023-01-19  2023-02-27
# 136                   lco_split_1_2023   lol  2023-01-19  2023-04-30
# 104          honor_league_opening_2023   lol  2023-01-20  2023-04-08
# 219                 cblol_2023_split_1   lol  2023-01-20  2023-04-16
# 209                   lla_opening_2023   lol  2023-01-22  2023-04-17
# 26            elite_series_spring_2023   lol  2023-01-22  2023-04-01
# 190                    gll_spring_2023   lol  2023-01-22  2023-04-03
# 96                     ebl_spring_2023   lol  2023-01-22  2023-04-04
# 170         cblol_academy_2023_split_1   lol  2023-01-22  2023-04-23
# 80        hitpoint_masters_spring_2023   lol  2023-01-22  2023-04-03
# 161        liga_portuguesa_spring_2023   lol  2023-01-22  2023-04-02
# 230         arabian_league_spring_2023   lol  2023-01-23  2023-04-02
# 187                    lcs_spring_2023   lol  2023-01-24  2023-04-11
# 210           pg_nationals_spring_2023   lol  2023-01-24  2023-04-04
# 93                     ljl_spring_2023   lol  2023-01-26  2023-04-18
# 59                     pcs_spring_2023   lol  2023-01-31  2023-03-13
# 24                     vcs_spring_2023   lol  2023-02-14  2023-05-03
# 85                     lec_spring_2023   lol  2023-03-08  2023-04-27
# 185      nacl_qualifiers_2_spring_2023   lol  2023-03-09  2023-04-03
# 207           pcs_spring_playoffs_2023   lol  2023-03-22  2023-04-12
# 150  emea_masters_spring_play_ins_2023   lol  2023-04-02  2023-04-08
# 51       emea_masters_spring_main_2023   lol  2023-04-09  2023-04-30
# 166         nacl_promotion_spring_2023   lol  2023-04-15  2023-04-24
# 134                           msi_2023   lol  2023-05-02  2023-05-22
# 165                   lrn_closing_2023   lol  2023-05-27  2023-08-21
# 4                ultraliga_summer_2023   lol  2023-05-28  2023-08-13
# 3                superliga_summer_2023   lol  2023-05-28  2023-08-19
# 22                     lpl_summer_2023   lol  2023-05-28  2023-08-19
# 76                     lfl_summer_2023   lol  2023-05-29  2023-08-15
# 84            prime_league_summer_2023   lol  2023-05-30  2023-08-19
# 11                    lrs_closing_2023   lol  2023-05-31  2023-08-28
# 132                    lcs_summer_2023   lol  2023-05-31  2023-08-22
# 148        lck_challengers_summer_2023   lol  2023-06-03  2023-08-25
# 12         liga_portuguesa_summer_2023   lol  2023-06-04  2023-08-19
# 169       hitpoint_masters_summer_2023   lol  2023-06-04  2023-08-19
# 1                      gll_summer_2023   lol  2023-06-04  2023-08-19
# 7                      nlc_summer_2023   lol  2023-06-04  2023-08-19
# 48                    lla_closing_2023   lol  2023-06-04  2023-08-27
# 2             elite_series_summer_2023   lol  2023-06-04  2023-08-19
# 131                   lco_split_2_2023   lol  2023-06-04  2023-08-01
# 10                     ebl_summer_2023   lol  2023-06-05  2023-08-19
# 6                      tcl_summer_2023   lol  2023-06-06  2023-08-19
# 149                    lck_summer_2023   lol  2023-06-06  2023-08-22
# 9             pg_nationals_summer_2023   lol  2023-06-06  2023-08-19
# 69                    nacl_summer_2023   lol  2023-06-08  2023-08-12
# 135                    ljl_summer_2023   lol  2023-06-08  2023-08-22
# 130                 cblol_2023_split_2   lol  2023-06-09  2023-09-10
# 37          cblol_academy_2023_split_2   lol  2023-06-11  2023-09-03
# 147         arabian_league_summer_2023   lol  2023-06-11  2023-08-13
# 75       nacl_qualifiers_1_summer_2023   lol  2023-06-15  2023-07-11
# 133                    lec_summer_2023   lol  2023-06-15  2023-08-01
# 8                     ljl_academy_2023   lol  2023-06-19  2023-08-12
# 23                     vcs_summer_2023   lol  2023-06-21  2023-09-12
# 168                    pcs_summer_2023   lol  2023-06-28  2023-09-12
# 0        nacl_qualifiers_2_summer_2023   lol  2023-07-20  2023-08-15
# 5             lpl_regional_finals_2023   lol  2023-08-03  2023-08-10
# 129           pcs_summer_playoffs_2023   lol  2023-08-09  2023-09-12
# 128           emea_masters_summer_2023   lol  2023-08-12  2023-09-10
# 167             lec_season_finals_2023   lol  2023-08-17  2023-09-12
# 267           lck_regional_finals_2023   lol  2023-08-24  2023-08-28
# 290         nacl_promotion_summer_2023   lol  2023-08-29  2023-09-04
# 347                   wqs_emea_na_2023   lol  2023-10-08  2023-10-09
#
#                                                 stages
# 352  [{'name': 'Regular Season', 'type': None, 'slu...
# 376  [{'name': 'Regular Season', 'type': None, 'slu...
# 25   [{'name': 'Regular Season', 'type': None, 'slu...
# 38   [{'name': 'Round 1', 'type': None, 'slug': 'ro...
# 255  [{'name': 'Regular Season', 'type': None, 'slu...
# 94   [{'name': 'Regular Season', 'type': None, 'slu...
# 99   [{'name': 'Regular Season', 'type': None, 'slu...
# 13   [{'name': 'Regular Season', 'type': None, 'slu...
# 41   [{'name': 'Regular Season', 'type': None, 'slu...
# 52   [{'name': 'Regular Season', 'type': None, 'slu...
# 86   [{'name': 'Round 1', 'type': None, 'slug': 'ro...
# 179  [{'name': 'Regular Season', 'type': None, 'slu...
# 137  [{'name': 'Regular Season', 'type': None, 'slu...
# 116  [{'name': 'Regular Season', 'type': None, 'slu...
# 188  [{'name': 'Regular Season', 'type': None, 'slu...
# 189  [{'name': 'Regular Season', 'type': None, 'slu...
# 60   [{'name': 'Regular Season', 'type': None, 'slu...
# 180  [{'name': 'Regular Season', 'type': None, 'slu...
# 171  [{'name': 'Regular Season', 'type': None, 'slu...
# 112  [{'name': 'Groups', 'type': None, 'slug': 'gro...
# 136  [{'name': 'Regular Season', 'type': None, 'slu...
# 104  [{'name': 'Regular Season', 'type': None, 'slu...
# 219  [{'name': 'Regular Season', 'type': None, 'slu...
# 209  [{'name': 'Regular Season', 'type': None, 'slu...
# 26   [{'name': 'Regular Season', 'type': None, 'slu...
# 190  [{'name': 'Regular Season', 'type': None, 'slu...
# 96   [{'name': 'Regular Season', 'type': None, 'slu...
# 170  [{'name': 'Regular Season', 'type': None, 'slu...
# 80   [{'name': 'Regular Season', 'type': None, 'slu...
# 161  [{'name': 'Regular Season', 'type': None, 'slu...
# 230  [{'name': 'Regular Season', 'type': None, 'slu...
# 187  [{'name': 'Regular Season', 'type': None, 'slu...
# 210  [{'name': 'Regular Season', 'type': None, 'slu...
# 93   [{'name': 'Regular Season', 'type': None, 'slu...
# 59   [{'name': 'Regular Season', 'type': None, 'slu...
# 24   [{'name': 'Regular Season', 'type': None, 'slu...
# 85   [{'name': 'Regular Season', 'type': None, 'slu...
# 185  [{'name': 'Groups', 'type': None, 'slug': 'gro...
# 207  [{'name': 'Playoffs', 'type': None, 'slug': 'p...
# 150  [{'name': 'Play In Groups', 'type': None, 'slu...
# 51   [{'name': 'Groups', 'type': None, 'slug': 'gro...
# 166  [{'name': 'knockouts', 'type': None, 'slug': '...
# 134  [{'name': 'Play In Knockouts', 'type': None, '...
# 165  [{'name': 'Regular Season', 'type': None, 'slu...
# 4    [{'name': 'Regular Season', 'type': None, 'slu...
# 3    [{'name': 'Regular Season', 'type': None, 'slu...
# 22   [{'name': 'Regular Season', 'type': None, 'slu...
# 76   [{'name': 'Regular Season', 'type': None, 'slu...
# 84   [{'name': 'Regular Season', 'type': None, 'slu...
# 11   [{'name': 'Regular Season', 'type': None, 'slu...
# 132  [{'name': 'Regular Season', 'type': None, 'slu...
# 148  [{'name': 'Regular Season', 'type': None, 'slu...
# 12   [{'name': 'Regular Season', 'type': None, 'slu...
# 169  [{'name': 'Regular Season', 'type': None, 'slu...
# 1    [{'name': 'Regular Season', 'type': None, 'slu...
# 7    [{'name': 'Regular Season', 'type': None, 'slu...
# 48   [{'name': 'Regular Season', 'type': None, 'slu...
# 2    [{'name': 'Regular Season', 'type': None, 'slu...
# 131  [{'name': 'Regular Season', 'type': None, 'slu...
# 10   [{'name': 'Regular Season', 'type': None, 'slu...
# 6    [{'name': 'Regular Season', 'type': None, 'slu...
# 149  [{'name': 'Regular Season', 'type': None, 'slu...
# 9    [{'name': 'Regular Season', 'type': None, 'slu...
# 69   [{'name': 'Regular Season', 'type': None, 'slu...
# 135  [{'name': 'Regular Season', 'type': None, 'slu...
# 130  [{'name': 'Regular Season', 'type': None, 'slu...
# 37   [{'name': 'Regular Season', 'type': None, 'slu...
# 147  [{'name': 'Regular Season', 'type': None, 'slu...
# 75   [{'name': 'Groups', 'type': None, 'slug': 'gro...
# 133  [{'name': 'Regular Season', 'type': None, 'slu...
# 8    [{'name': 'Regular Season', 'type': None, 'slu...
# 23   [{'name': 'Regular Season', 'type': None, 'slu...
# 168  [{'name': 'Regular Season', 'type': None, 'slu...
# 0    [{'name': 'Groups', 'type': None, 'slug': 'gro...
# 5    [{'name': 'Regional Finals', 'type': None, 'sl...
# 129  [{'name': 'Playoffs', 'type': None, 'slug': 'p...
# 128  [{'name': 'Play In Groups', 'type': None, 'slu...
# 167  [{'name': 'Regional Finals', 'type': None, 'sl...
# 267  [{'name': 'regional_qualifier', 'type': None, ...
# 290  [{'name': 'knockouts', 'type': None, 'slug': '...
# 347  [{'name': 'knockouts', 'type': None, 'slug': '...

# %%
ELO_players = pd.DataFrame(columns = ['id', 'handle', 'ELO'])
ELO_players
# Out:
# Empty DataFrame
# Columns: [id, handle, ELO]
# Index: []

# %%
ELO = new_leagues.loc[new_leagues['id'] == 107407335299756365]['ELO'].item()
ELO
# Out:
# 1000

# %%
def start_elo(player_id, league_id, ELO_players, new_leagues):
    handle = players.loc[players['player_id'] == player_id]['handle'].item()
    ELO = new_leagues.loc[new_leagues['id'] == int(league_id)]['ELO'].item()
    elop = pd.DataFrame([{'id': player_id, 'handle' : handle, 'ELO': ELO}])
    ELO_players = pd.concat([ELO_players, elop], ignore_index = True)
    return ELO_players

# %%
def get_elo(game_id,league_id, ELO_players,new_leagues):
    elo_blue_side = 0
    elo_red_side = 0
    players_blue = []
    players_red = []
    for i in range(1, 6, 1):
        participant_mapping = 'participantMapping.{}'.format(i)
        player_id = mapping_data.loc[mapping_data['esportsGameId'] == game_id][participant_mapping].item()
        if player_id not in players.values:
            continue
        players_blue.append(player_id)
        if player_id not in ELO_players.values :
            ELO_players = start_elo(player_id, league_id, ELO_players, new_leagues)
        elo_blue_side += ELO_players.loc[ELO_players['id'] == player_id]['ELO'].item()
    for i in range(6, 11, 1):
        participant_mapping = 'participantMapping.{}'.format(i)
        player_id = mapping_data.loc[mapping_data['esportsGameId'] == game_id][participant_mapping].item()
        if player_id not in players.values:
            continue
        players_red.append(player_id)
        if player_id not in ELO_players.values :
            ELO_players =start_elo(player_id, league_id, ELO_players, new_leagues)
        elo_red_side += ELO_players.loc[ELO_players['id'] == player_id]['ELO'].item()
    if len(players_blue) == 0:
        len_players_blue = 1
    else: 
        len_players_blue = len(players_blue)
    if len(players_red) == 0:
        len_players_red = 1
    else: 
        len_players_red = len(players_red)
    
    return elo_blue_side/len_players_blue, elo_red_side/len_players_red, players_blue, players_red, ELO_players

# %%
def elo_calc(r_a, r_b, k, result, name):
    e_a = 1 / (1 + pow(10, ((r_b - r_a)/400)))
    e_b = 1 / (1 + pow(10, ((r_a - r_b)/400)))
    if result == 'win':
        r = 1
    else:
        r = 0
    change_a = int(k * (r - e_a)) + 10 * (name == 'knockouts')
    change_b = int(k * (1 - r - e_b)) + 10 * (name == 'knockouts')
    return change_a, change_b

# %%
def elo_change(elo_change_blue, elo_change_red, ELO_players, players_blue, players_red, elo_blue, elo_red):
    for player in players_blue:
        elo = ELO_players.loc[ELO_players['id'] == player]['ELO'].item()
        #diff = elo - elo_blue
        #if (diff / elo) > (0.2 * elo):
        #    elo *= 0.9
        new_elo = elo + elo_change_blue
        ELO_players.loc[ELO_players['id'] == player, 'ELO'] = new_elo
    for player in players_red:
        elo = ELO_players.loc[ELO_players['id'] == player]['ELO'].item()
        #diff = elo - elo_red
        #if (diff / elo) > (0.2 * elo):
        #    elo *= 0.9
        new_elo = elo + elo_change_red
        ELO_players.loc[ELO_players['id'] == player, 'ELO'] = new_elo
    return ELO_players

# %%
def advance_elo_one_month(year_month, ELO_players, new_leagues):
    for index, tournament in tournaments.iterrows():
        start_date = tournament.get("startDate", "")
        if start_date.startswith(year_month):
            if int(tournament['leagueId']) not in new_leagues.values:
                print(tournament['slug'] ,' not in leagues')
                continue
            print(f"Processing {tournament['slug']}")
            for stage in tournament["stages"]:
                for section in stage["sections"]:
                    for match in section["matches"]:
                        for game in match["games"]:
                            if game['id'] not in mapping_data.values:
                                    continue
                            if game["state"] == "completed":
                                elo_blue_side, elo_red_side, players_blue, players_red ,ELO_players = get_elo(game['id'], tournament['leagueId'], ELO_players,new_leagues)
                                k = 30 + 20 * (match['strategy']['count'] > 4)
                                result_blue_side = game['teams'][0]['result']['outcome']
                                elo_change_blue, elo_change_red = elo_calc(elo_blue_side, elo_red_side, k, result_blue_side, stage['name'])
                                ELO_players = elo_change(elo_change_blue, elo_change_red, ELO_players, players_blue, players_red, elo_blue_side, elo_red_side)
    
    return ELO_players

# %%
# %%time
ELO_players = advance_elo_one_month('2020-01', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-02', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-03', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-04', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-05', ELO_players, new_leagues)
ELO_players['ELO_06_2020'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
ELO_players = advance_elo_one_month('2020-06', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-07', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-08', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-09', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-10', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-11', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2020-12', ELO_players, new_leagues)
ELO_players['ELO_12_2020'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
# Out:
# Processing lpl_spring_2020
# Processing lcs_spring_2020
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[8], line 16, in advance_elo_one_month(year_month, ELO_players, new_leagues)
#      14         continue
#      15 if game["state"] == "completed":
# ---> 16     elo_blue_side, elo_red_side, players_blue, players_red ,ELO_players = get_elo(game['id'], tournament['leagueId'], ELO_players,new_leagues)
#      17     k = 30 + 20 * (match['strategy']['count'] > 4)
#      18     result_blue_side = game['teams'][0]['result']['outcome']
#
# NameError: name 'get_elo' is not defined

# %%
# %%time
ELO_players = advance_elo_one_month('2021-01', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-02', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-03', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-04', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-05', ELO_players, new_leagues)
ELO_players['ELO_06_2021'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
ELO_players = advance_elo_one_month('2021-06', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-07', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-08', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-09', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-10', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-11', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2021-12', ELO_players, new_leagues)
ELO_players['ELO_12_2021'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
# Out:
# Processing lec_spring_2021
# Processing lpl_spring_2021
# Processing greek_legends_league_spring_2021
# belgian_league_2021_split1  not in leagues
# dutch_league_2021_split1  not in leagues
# Processing pg_nationals_spring_2021
# Processing lck_spring_2021
# Processing lcs_lock_in_2021
# baltic_masters_2021_spring  not in leagues
# Processing cblol_split_1_2021
# Processing superliga_spring_2021
# Processing lck_challengers_spring_2021
# Processing prime_league_spring_2021
# Processing cblol_academy_split_1_2021
# Processing nlc_2021_split1
# Processing ultraliga_spring_2021
# Processing lfl_2021_spring
# lcs_academy_spring_2021  not in leagues
# tal_winter_2021  not in leagues
# Processing ljl_spring_2021
# Processing tcl_winter_2021
# Processing hitpoint_masters_spring_2021
# Processing liga_portuguesa_spring_2021
# Processing esports_balkan_league_spring_2021
# Processing lla_opening_2021
# Processing lcs_spring_2021
# Processing lcl_spring_2021
# Processing pcs_spring_2021
# Processing lco_split_1_2021
# Processing mss_2021
# Processing european_masters_spring_2021_play_ins
# lcs_proving_grounds_spring_2021  not in leagues
# Processing european_masters_spring_2021_main_event
# Processing msi_2021
# Processing prime_league_summer_2021
# Processing greek_legends_league_summer_2021
# Processing ultraliga_summer_2021
# belgian_league_2021_split2  not in leagues
# Processing superliga_summer_2021
# Processing lfl_2021_summer
# Processing liga_portuguesa_summer_2021
# Processing pg_nationals_summer_2021
# dutch_league_2021_split2  not in leagues
# Processing nlc_summer_2021
# lcs_academy_summer_2021  not in leagues
# Processing lcs_summer_2021
# Processing lpl_summer_2021
# Processing cblol_academy_split_2_2021
# Processing cblol_split_2_2021
# Processing tcl_summer_2021
# Processing lck_challengers_summer_2021
# Processing lck_summer_2021
# Processing esports_balkan_league_summer_2021
# baltic_masters_2021_summer  not in leagues
# tal_summer_2021  not in leagues
# Processing lec_summer_2021
# Processing lco_split_2_2021
# Processing hitpoint_masters_summer_2021
# Processing ljl_summer_2021
# Processing lla_closing_2021
# Processing lcl_summer_2021
# Processing pcs_summer_2021
# Processing european_masters_summer_2021_play_ins
# Processing european_masters_summer_2021_main_event
# Processing lpl_regional_finals_2021
# Processing ljl_academy_2021
# Processing lck_regional_finals_2021
# Processing lla_promotion_2021
# lcs_proving_grounds_summer_2021  not in leagues
# Processing worlds_2021
# Processing vcs_winter_2021
# CPU times: user 10min 53s, sys: 194 ms, total: 10min 53s
# Wall time: 13min 5s

# %%
# %%time
ELO_players = advance_elo_one_month('2022-01', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-02', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-03', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-04', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-05', ELO_players, new_leagues)
ELO_players['ELO_06_2022'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
ELO_players = advance_elo_one_month('2022-06', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-07', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-08', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-09', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-10', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-11', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2022-12', ELO_players, new_leagues)
ELO_players['ELO_12_2022'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
# Out:
# Processing ultraliga_spring_2022
# Processing nlc_spring_2022
# Processing prime_league_spring_2022
# Processing lec_spring_2022
# Processing lfl_2022_spring
# Processing lck_challengers_spring_2022
# Processing superliga_spring_2022
# Processing lpl_spring_2022
# Processing lck_spring_2022
# Processing lcs_lock_in_2022
# Processing elite_series_spring_2022
# Processing esports_balkan_league_spring_2022
# Processing greek_legends_league_spring_2022
# Processing liga_portuguesa_spring_2022
# Processing pg_nationals_spring_2022
# Processing hitpoint_masters_spring_2022
# honor_division_opening_2022  not in leagues
# lcs_academy_spring_2022  not in leagues
# tal_winter_2022  not in leagues
# Processing tcl_winter_2022
# Processing cblol_split_1_2022
# Processing lco_split_1_2022
# Processing cblol_academy_split_1_2022
# honor_league_opening_2022  not in leagues
# elements_league_opening_2022  not in leagues
# volcano_league_opening_2022  not in leagues
# golden_league_opening_2022  not in leagues
# master_flow_league_opening_2022  not in leagues
# stars_league_opening_2022  not in leagues
# Processing lla_opening_2022
# Processing lcs_spring_2022
# Processing ljl_spring_2022
# Processing lcl_spring_2022
# Processing vcs_spring_2022
# Processing pcs_spring_2022
# lcs_proving_grounds_spring_2022  not in leagues
# Processing european_masters_spring_2022_play_ins
# Processing tcl_summer_2022
# Processing european_masters_spring_2022_main_event
# Processing college_championship_2022
# Processing lck_academy_01_2022
# tft_event_summer  not in leagues
# Processing lck_summer_2022
# Processing lck_challengers_summer_2022
# Processing msi_2022
# master_flow_league_closing_2022  not in leagues
# golden_league_closing_2022  not in leagues
# honor_league_closing_2022  not in leagues
# honor_division_closing_2022  not in leagues
# elements_league_closing_2022  not in leagues
# volcano_league_closing_2022  not in leagues
# stars_league_closing_2022  not in leagues
# Processing greek_legends_league_summer_2022
# Processing superliga_summer_2022
# Processing nlc_summer_2022
# Processing ultraliga_summer_2022
# Processing prime_league_summer_2022
# lcs_amateur_circuit_summer_2022  not in leagues
# Processing lfl_2022_summer
# Processing ljl_academy_2022
# Processing lco_split_2_2022
# Processing esports_balkan_league_summer_2022
# Processing elite_series_summer_2022
# Processing pg_nationals_summer_2022
# Processing hitpoint_masters_summer_2022
# Processing liga_portuguesa_summer_2022
# lcs_academy_summer_2022  not in leagues
# tal_summer_2022  not in leagues
# Processing lpl_summer_2022
# Processing cblol_split_2_2022
# Processing lla_closing_2022
# Processing ljl_summer_2022
# Processing cblol_academy_split_2_2022
# Processing lcs_summer_2022
# Processing lec_summer_2022
# Processing pcs_summer_2022
# lcs_amateur_circuit_summer_2022  not in leagues
# Processing vcs_summer_2022
# stars_league_super_finals_2022  not in leagues
# volcano_league_super_finals_2022  not in leagues
# lcs_proving_grounds_summer_2022  not in leagues
# golden_league_super_finals_2022  not in leagues
# Processing european_masters_summer_2022_play_ins
# Processing european_masters_summer_2022_main_event
# Processing lck_regional_finals_2022
# Processing lpl_regional_finals_2022
# Processing lla_promotion_2022
# Processing worlds_2022
# CPU times: user 12min 53s, sys: 246 ms, total: 12min 53s
# Wall time: 15min 29s

# %%
# %%time
#ELO_players = advance_elo_one_month('2023-01', ELO_players, new_leagues)
#ELO_players = advance_elo_one_month('2023-02', ELO_players, new_leagues)
#ELO_players = advance_elo_one_month('2023-03', ELO_players, new_leagues)
#ELO_players = advance_elo_one_month('2023-04', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-05-02', ELO_players, new_leagues)
ELO_players['ELO_05_2023'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
ELO_players = advance_elo_one_month('2023-05-28', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-06', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-07', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-08', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-09', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-10', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-11', ELO_players, new_leagues)
ELO_players = advance_elo_one_month('2023-12', ELO_players, new_leagues)
ELO_players['ELO_12_2023'] = ELO_players['ELO']
#ELO_players['ELO'] = ELO_players['ELO'].apply(lambda x: x*0.9)
# Out:
# Processing msi_2023
# Processing ultraliga_summer_2023
# Processing superliga_summer_2023
# Processing lpl_summer_2023
# Processing lck_challengers_summer_2023
# Processing liga_portuguesa_summer_2023
# Processing hitpoint_masters_summer_2023
# Processing gll_summer_2023
# Processing nlc_summer_2023
# Processing lla_closing_2023
# Processing elite_series_summer_2023
# Processing lco_split_2_2023
# Processing ebl_summer_2023
# Processing tcl_summer_2023
# Processing lck_summer_2023
# Processing pg_nationals_summer_2023
# Processing nacl_summer_2023
# Processing ljl_summer_2023
# Processing cblol_2023_split_2
# Processing cblol_academy_2023_split_2
# Processing arabian_league_summer_2023
# Processing nacl_qualifiers_1_summer_2023
# Processing lec_summer_2023
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:9
#
# Cell In[8], line 16, in advance_elo_one_month(year_month, ELO_players, new_leagues)
#      14         continue
#      15 if game["state"] == "completed":
# ---> 16     elo_blue_side, elo_red_side, players_blue, players_red ,ELO_players = get_elo(game['id'], tournament['leagueId'], ELO_players,new_leagues)
#      17     k = 30 + 20 * (match['strategy']['count'] > 4)
#      18     result_blue_side = game['teams'][0]['result']['outcome']
#
# Cell In[16], line 13, in get_elo(game_id, league_id, ELO_players, new_leagues)
#      11     players_blue.append(player_id)
#      12     if player_id not in ELO_players.values :
# ---> 13         ELO_players = start_elo(player_id, league_id, ELO_players, new_leagues)
#      14     elo_blue_side += ELO_players.loc[ELO_players['id'] == player_id]['ELO'].item()
#      15 for i in range(6, 11, 1):
#
# Cell In[24], line 3, in start_elo(player_id, league_id, ELO_players, new_leagues)
#       1 def start_elo(player_id, league_id, ELO_players, new_leagues):
#       2     handle = players.loc[players['player_id'] == player_id]['handle'].item()
# ----> 3     ELO = new_leagues.loc[new_leagues['id'] == int(league_id)]['ELO'].item()
#       4     elop = pd.DataFrame([{'id': player_id, 'handle' : handle, 'ELO': ELO}])
#       5     ELO_players = pd.concat([ELO_players, elop],ignore_index = True)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/base.py:350, in IndexOpsMixin.item(self)
#     348 if len(self) == 1:
#     349     return next(iter(self))
# --> 350 raise ValueError("can only convert an array of size 1 to a Python scalar")
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
ELO_players.sort_values(by =['ELO'], ascending = False, inplace =True)

# %%
pd.set_option('display.max_rows', None)

# %%
player_id = '103495716738607011'
print(players.loc[players['player_id'] == player_id]['handle'].item(), ' not in players')
# Out:
# Lot  not in players

# %%
ELO_players
# Out:
#                       id       handle   ELO ELO_05_2023 ELO_12_2023
# 40    102186485482484390        Doran  1835        1730        1835
# 41     98767975916458257       Peanut  1835        1730        1835
# 42     99871276342168416        Chovy  1835        1730        1835
# 44    105501709748188393      Delight  1835        1730        1835
# 43    107492068702410338         Peyz  1835        1730        1835
# 64    100205573984889078      MISSING  1830        1900        1830
# 60    101388912796120370          369  1830        1900        1830
# 61    101671284628761661       Kanavi  1830        1900        1830
# 63     98767975906852059        Ruler  1830        1900        1830
# 62     99566404803543690       knight  1821        1900        1821
# 4     105516578130811296           ON  1820        1820        1820
# 251    99566404810113891       TheShy  1796         NaN        1796
# 252   102192147302633932       Weiwei  1796         NaN        1796
# 253    98767975914916595       Xiaohu  1796         NaN        1796
# 254   100205573983550103        Light  1796         NaN        1796
# 255    99566404817393644        Crisp  1796         NaN        1796
# 52     98767991747728851        Faker  1772        1750        1772
# 24     99322214629661297        Mikyx  1712        1709        1712
# 187    99124844341128030         FoFo  1712         NaN        1712
# 20     99566406047571736  BrokenBlade  1712        1709        1712
# 21    105537190986692036         Yike  1712        1709        1712
# 22     98767975968177297         Caps  1712        1709        1712
# 23     98767975961872793    Hans Sama  1712        1709        1712
# 186   102191852281361066       JieJie  1709         NaN        1709
# 790    99566404541006806       Aiming  1697         NaN        1697
# 791    99871276332909841      Lehends  1697         NaN        1697
# 789    98767975949926165          Bdd  1697         NaN        1697
# 788    98767975940969117         Cuzz  1697         NaN        1697
# 787    99566404532924465         Kiin  1697         NaN        1697
# 213   106368556422916908        Creme  1695         NaN        1695
# 212   102192182794613438          Aki  1695         NaN        1695
# 1     105516152837078491          XUN  1693        1820        1693
# 0     103478281356330346          Bin  1693        1820        1693
# 2      99566404798393925        Yagao  1693        1820        1693
# 3     106368692529261498          Elk  1693        1820        1693
# 776    99566404532361623         Deft  1690         NaN        1690
# 185   106368720864853141          Ale  1681         NaN        1681
# 189    98767991785832912        Meiko  1681         NaN        1681
# 196   108547753406304556         YSKM  1673         NaN        1673
# 773   103495716771322725        Canna  1671         NaN        1671
# 774   100725844994345151       Canyon  1671         NaN        1671
# 775   100725844988653773    ShowMaker  1671         NaN        1671
# 188    98767991763297584          Uzi  1671         NaN        1671
# 240   101388912816278953         Mark  1669         NaN        1669
# 239    99566404823220763   JackeyLove  1669         NaN        1669
# 238    99566404811346612       Rookie  1669         NaN        1669
# 237    99566404820654675         Tian  1669         NaN        1669
# 34     99566406444168246        Woody  1669        1666        1669
# 33     99566406463329124         Wako  1669        1666        1669
# 197   110547813514542545     Tianzhen  1669         NaN        1669
# 30    104573202011010010         Azhi  1669        1666        1669
# 31    101971954398227333       JunJia  1669        1666        1669
# 236   107597467455543061      Wayward  1669         NaN        1669
# 32    109642949927749506         ubao  1666        1666        1666
# 215   104287365097341858        ppgod  1665         NaN        1665
# 214    99566404830718870         Able  1665         NaN        1665
# 211   107597388256890710       shanji  1665         NaN        1665
# 12    101422378834657466         Gori  1664        1664        1664
# 13     98926509773553311      Stixxay  1664        1664        1664
# 10     98926509838831804     Licorice  1664        1664        1664
# 11    104573330241006058        River  1664        1664        1664
# 14     98926509793730393         huhi  1664        1664        1664
# 18    107251575502514974        Sty1e  1658        1658        1658
# 218   107597490826236285       Strive  1657         NaN        1657
# 199   107597344477531938          Ahn  1657         NaN        1657
# 208    98767975951139628        Scout  1646         NaN        1646
# 209   101388912814247335         GALA  1646         NaN        1646
# 210   103817065229388803         Hang  1646         NaN        1646
# 206   108477153941144313         Zika  1646         NaN        1646
# 207    99871276342823057       Tarzan  1646         NaN        1646
# 191    99566404808749349       H4cker  1644         NaN        1644
# 220   110547690694797001      Feather  1642         NaN        1642
# 58    105388936922706146    Berserker  1642        1642        1642
# 59     98767991801635485         Zven  1642        1642        1642
# 57    103524169393525450       EMENES  1642        1642        1642
# 56     99101098218071815       Blaber  1642        1642        1642
# 55    102206337829139149        Fudge  1642        1642        1642
# 200   108477164655610574        Winkk  1632         NaN        1632
# 198   103461966884669326       Cryin   1632         NaN        1632
# 54    103495716561790834        Keria  1626        1750        1626
# 53    103495716775975785     Gumayusi  1626        1750        1626
# 51    105320682452092471         Oner  1626        1750        1626
# 50    105320680474347057         Zeus  1626        1750        1626
# 256   109784344243547583        Leave  1620         NaN        1620
# 263   110949698397005094     Thesnake  1618         NaN        1618
# 193    99566404797171439          Lwx  1617         NaN        1617
# 192   108013460749990840         Care  1617         NaN        1617
# 190   106891309322187667    xiaolaohu  1617         NaN        1617
# 194    99566404801201868       QiuQiu  1617         NaN        1617
# 195    98767975962342669         iBoy  1612         NaN        1612
# 272   109784410134967214          Lzq  1609         NaN        1609
# 247   102808727762706248       Shad0w  1607         NaN        1607
# 221   105516622825169657      Breathe  1605         NaN        1605
# 222   103461966880868232          Wei  1605         NaN        1605
# 224   109784511181059004           LP  1605         NaN        1605
# 223   109784590066548371     Tangyuan  1605         NaN        1605
# 225    99566404813905681        LvMao  1604         NaN        1604
# 274   105516558751291781         Lele  1601         NaN        1601
# 258   110547590326456015  xiaohuangre  1599         NaN        1599
# 35    106702283617298068         tol2  1599        1644        1599
# 234   103817053209529905     huanfeng  1597         NaN        1597
# 250   105516599464787723         Zhuo  1596         NaN        1596
# 249   103478281359738222       Photic  1596         NaN        1596
# 248   101388912814667094        Angel  1596         NaN        1596
# 246   106368596012350493   Invincible  1596         NaN        1596
# 243   103103687119049758        Forge  1590         NaN        1590
# 273   103478281402167891          XLB  1589         NaN        1589
# 261   107568618763485355         Wen1  1588         NaN        1588
# 235   103478281358165356     yuyanjia  1587         NaN        1587
# 226   108477164506118803         Cube  1586         NaN        1586
# 227   109784703569533478         Heng  1586         NaN        1586
# 228   104287400430814502       Shanks  1586         NaN        1586
# 229    99566404819916503         Hope  1586         NaN        1586
# 230   103478281389584950       Iwandy  1586         NaN        1586
# 264   106368460937685742          Lpc  1585         NaN        1585
# 217   102854899616784557        Leyan  1578         NaN        1578
# 219   106368497875598272        Assum  1578         NaN        1578
# 216   109784472606547975       Xiaoxu  1578         NaN        1578
# 244   104573129055417270        Doggo  1577         NaN        1577
# 8     105512438075390766          Ceo  1576        1661        1576
# 7     104266800049354578        Mireu  1576        1661        1576
# 6      98767975971974446        Oddie  1576        1661        1576
# 5     108443042455354918         Bong  1576        1661        1576
# 9     107583616307712318        Lyonz  1576        1661        1576
# 267   107597347065845472    xiaoyueji  1575         NaN        1575
# 181   109784262721182010         pinz  1575         NaN        1575
# 268   110547865297590237       Bonnie  1573         NaN        1573
# 783    99566404797900723         Clid  1573         NaN        1573
# 269   106368678820506543         neny  1571         NaN        1571
# 266   108511159661913839       Fisher  1569         NaN        1569
# 262   101388912799069496     beishang  1563         NaN        1563
# 257   106368619727273011     fearness  1559         NaN        1559
# 270   107597400971826936       Dreamm  1559         NaN        1559
# 184   107597440669175654       Harder  1558         NaN        1558
# 27     99566407748213242      tinowns  1557        1672        1557
# 28    100174429498252618        Route  1557        1672        1557
# 25     99566407763820708         Robo  1557        1672        1557
# 26    103525195752578562         Croc  1557        1672        1557
# 29    101383793153915529         Ceos  1557        1672        1557
# 259   110547595875608233          1xn  1552         NaN        1552
# 784   103478281361900912         Zeka  1550         NaN        1550
# 786   100205573444701958         Life  1550         NaN        1550
# 785    99871276340698623        Viper  1550         NaN        1550
# 782   100428088879195423       Kingen  1550         NaN        1550
# 233    99566404534366144         Ucal  1549         NaN        1549
# 231   103729432252832975         Hoya  1549         NaN        1549
# 37    103535282076301190         Aria  1548        1644        1548
# 36    100754278890207800        Steal  1548        1644        1548
# 38    100285330144336367      Yutapon  1548        1644        1548
# 39    104016425624023728         Harp  1548        1644        1548
# 15    107330029738468255        Kiaya  1547        1658        1547
# 16     98767975918707483         Levi  1547        1658        1547
# 245    98767975903712783     SwordArt  1545         NaN        1545
# 242    99566404802630511         Ning  1545         NaN        1545
# 201   107597444985083651       Decade  1540         NaN        1540
# 17    107251572267658009         Kati  1538        1658        1538
# 265    99566404837520336       Baolan  1536         NaN        1536
# 47     98926509846377469        Nisqy  1533        1584        1533
# 48    102787200044335760       Carzzy  1533        1584        1533
# 49     99322214606051339    Hylissang  1533        1584        1533
# 46    103877629120745120       Elyoya  1533        1584        1533
# 45    105320663958816293        Chasy  1533        1584        1533
# 183   107597470202646380        Zorah  1533         NaN        1533
# 179   103103555079018097          Zdz  1533         NaN        1533
# 180   107597411688435553      Xiaohao  1533         NaN        1533
# 260   107597376599119596       yaoyao  1530         NaN        1530
# 182   110547990270115348     zhiqiuyi  1521         NaN        1521
# 271    99566404826169385         Mole  1521         NaN        1521
# 19    102849319860638077          Zin  1518        1658        1518
# 232   107597339246973242     Beichuan  1518         NaN        1518
# 241   109784647310737799         Hery  1517         NaN        1517
# 803   105501850450507181       FIESTA  1511         NaN        1511
# 205    99566404806883067      Jinjiao  1499         NaN        1499
# 203   108477151747130094      haichao  1499         NaN        1499
# 778    99566404525897139         UmTi  1497         NaN        1497
# 777   103103696693473944       Morgan  1497         NaN        1497
# 779   105320670306436651         Hena  1497         NaN        1497
# 1230  100356590519370319     Humanoid  1492         NaN        1492
# 1228  103536968829352943    Oscarinin  1492         NaN        1492
# 1232  102181528883745160       Trymbi  1492         NaN        1492
# 1231  105501717406803640         Noah  1492         NaN        1492
# 1229  100238780551262852       Razork  1492         NaN        1492
# 806   105501790021137688        Clear  1490         NaN        1490
# 1203  105515229738531937         Adam  1488         NaN        1488
# 780   105320699390649600        Juhan  1488         NaN        1488
# 204   105530583598805234        Envyy  1484         NaN        1484
# 796   105501802535116331          Jun  1478         NaN        1478
# 802   105501846040405864       Sylvie  1476         NaN        1476
# 804   106267619732229182        Peter  1476         NaN        1476
# 1204  105830645287286396         Sheo  1473         NaN        1473
# 1207  102787200059605684       Labrov  1473         NaN        1473
# 178   110547957837987327           0N  1473         NaN        1473
# 1205  105554437688383476          nuc  1473         NaN        1473
# 1206  101389749297430422      Crownie  1473         NaN        1473
# 202   101388912805688644       Meteor  1469         NaN        1469
# 805   110219103969081067         Quad  1465         NaN        1465
# 1193   99322214598412197      Odoamne  1438         NaN        1438
# 1197  103536921518408674        LIMIT  1438         NaN        1438
# 1195  100174547541438669    Abbedagge  1438         NaN        1438
# 1196   99322214238585389       Patrik  1438         NaN        1438
# 1194  105501794903516897        Peach  1438         NaN        1438
# 781   103495716565722998         FATE  1432         NaN        1432
# 1213   98767975944639514          Evi  1425         NaN        1425
# 1217  104711186576765525        Mersa  1425         NaN        1425
# 1216  103461966879623046      Flakked  1425         NaN        1425
# 1215  103877659831635672       Vetheo  1425         NaN        1425
# 1214   99124844325223302       Jankos  1425         NaN        1425
# 770   108205130709313212      kyeahoo  1410         NaN        1410
# 318   108205130200366557       Callme  1405         NaN        1405
# 797   105705431649727017       Burdol  1405         NaN        1405
# 320   108205131490043598           HH  1400         NaN        1400
# 317   108205131143802891       Sounda  1400         NaN        1400
# 1323  109642949457528702         1116  1397         NaN        1397
# 1325  104573210012169189        Keres  1397         NaN        1397
# 1324   98767975924333750        Betty  1397         NaN        1397
# 1322  109642956314454111     Kongyue   1397         NaN        1397
# 1321  106470390660915203        LIKAI  1397         NaN        1397
# 799   104284310661848687       Clozer  1395         NaN        1395
# 798   106267386230851795       Willer  1395         NaN        1395
# 800    99566404526777331        Teddy  1395         NaN        1395
# 801   105530584812980593         Kael  1395         NaN        1395
# 1234  102787199999443508    Agresivoo  1385         NaN        1385
# 1212  105501861909424007    JeongHoon  1382         NaN        1382
# 1210  103889902476986558        LIDER  1382         NaN        1382
# 1209  103495716715079553          113  1382         NaN        1382
# 1208  101389713973624205         Finn  1382         NaN        1382
# 1211   99322214620375780        Kobbe  1382         NaN        1382
# 316   109550796116180074       Mihile  1380         NaN        1380
# 1318  106470392084689216       JimieN  1379         NaN        1379
# 1317   98767975915355341       Gemini  1379         NaN        1379
# 1316   99566406483009320         Rest  1379         NaN        1379
# 1319  107760720477800166        Shunn  1379         NaN        1379
# 1320   99566406485280528       ShiauC  1379         NaN        1379
# 331   103524794709678777        vital  1377         NaN        1377
# 1233  106033841485703441           Bo  1372         NaN        1372
# 794   106288134875041032      BuLLDoG  1370         NaN        1370
# 795   105501797931408936      Taeyoon  1370         NaN        1370
# 792   104266795407626462         DuDu  1370         NaN        1370
# 793   104266797862156067     YoungJae  1370         NaN        1370
# 1201  103536921420956640         Comp  1364         NaN        1364
# 1198  102181564372406674     Szygenda  1364         NaN        1364
# 834   103935361633728922          Vzz  1364         NaN        1364
# 1200  100482247959137902      Larssen  1364         NaN        1364
# 833   106301975219458494        Six10  1364         NaN        1364
# 831   105515294798291232          ACD  1364         NaN        1364
# 832   105536930572842229         Cboi  1364         NaN        1364
# 1202  105519724699493915     Advienne  1364         NaN        1364
# 835   104738081038726353        Click  1364         NaN        1364
# 1199   99566406053904433      Malrang  1364         NaN        1364
# 1224  107621095379170267       Daglas  1360         NaN        1360
# 280   105501816646382923     Thanatos  1358         NaN        1358
# 281   106267599829820917        Lucid  1358         NaN        1358
# 282   107492063150003806      Pullbae  1356         NaN        1356
# 769   105320703008048707        Croco  1354         NaN        1354
# 284   106267614244899897        Bible  1345         NaN        1345
# 1362  109784681589931709    KennyChan  1343         NaN        1343
# 768    98767975938371599       Rascal  1342         NaN        1342
# 1220  101389737455173027      Sertuss  1342         NaN        1342
# 1222  101389760981745081         Doss  1342         NaN        1342
# 1221  104737951126648199      Exakick  1342         NaN        1342
# 1218  105514974275992586   Irrelevant  1342         NaN        1342
# 772   100725844993017474        BeryL  1342         NaN        1342
# 1219  105519722481834694      Markoon  1342         NaN        1342
# 771   107492114500277895       Paduck  1342         NaN        1342
# 283   106267600924403194        Rahel  1339         NaN        1339
# 340   101388913291808185       Kellin  1334         NaN        1334
# 927   105576891638502799       Kinatu  1333         NaN        1333
# 931   103495716560217968         Vsta  1333         NaN        1333
# 930   103678738910712347       Marble  1333         NaN        1333
# 929   109703896774429378       DasheR  1333         NaN        1333
# 928    98767975952532107        Blank  1333         NaN        1333
# 1223  105732582273104165       Photon  1332         NaN        1332
# 1225   98767975948505333        Perkz  1332         NaN        1332
# 1226   99322214653265200        Upset  1332         NaN        1332
# 1227  103461966878377860       Kaiser  1332         NaN        1332
# 1336  109691839332751409     Solokill  1302         NaN        1302
# 1340   98767975956663486      Kaiwing  1302         NaN        1302
# 1339  101428372795092403          MnM  1302         NaN        1302
# 1338  107705431058397645    Pretender  1302         NaN        1302
# 301   107492121209956865      PerfecT  1298         NaN        1298
# 556   100438528849437575          Mia  1286         NaN        1286
# 302   107454953423394142       HamBak  1286         NaN        1286
# 303   107492030596737445       Feisty  1286         NaN        1286
# 304   109625891896082370        Hype   1286         NaN        1286
# 305   107492119089043087          Way  1286         NaN        1286
# 297   109523141015834041      Grizzly  1285         NaN        1285
# 877   101383793881527569      FakeGod  1285         NaN        1285
# 878   105913341225643811        Tomio  1285         NaN        1285
# 879   106857864117137093        Young  1285         NaN        1285
# 880   105957599019114812        Meech  1285         NaN        1285
# 881    98926509843809391       Zeyzal  1285         NaN        1285
# 956   103478281332503056     ProDelta  1284         NaN        1284
# 953   100205576295412145       CarioK  1284         NaN        1284
# 954    99566407782924807     dyNquedo  1284         NaN        1284
# 955   101388912784979237         Bvoy  1284         NaN        1284
# 952   101388913280994733        Wizer  1284         NaN        1284
# 276   108366332471078988       Sponge  1283         NaN        1283
# 277   107492116585043595        SeTab  1283         NaN        1283
# 1129  107577678283425574      Trixter  1283         NaN        1283
# 275   108205130568869560         Frog  1283         NaN        1283
# 134   103877632442764991        Marky  1282         NaN        1282
# 135   107464179845128878         Isma  1282         NaN        1282
# 136   104711049101664016    Fresskowy  1282         NaN        1282
# 137   103536968833612789         Supa  1282         NaN        1282
# 138   107564404490889053       Alvaro  1282         NaN        1282
# 1111  109782987645004350       Sudzzi  1280         NaN        1280
# 1113   98926509797315114      Dardoch  1280         NaN        1280
# 1110  110536248987966005         Chad  1280         NaN        1280
# 1112  101383793885656347          Neo  1280         NaN        1280
# 645   104668539132702977         Kevy  1279         NaN        1279
# 752   105511293284046174      Destroy  1277         NaN        1277
# 753   102235771563397600       Ferret  1277         NaN        1277
# 754   101422616414907159        Kofte  1277         NaN        1277
# 755   105320695377750123          BAO  1277         NaN        1277
# 756   103805069759346933        Parus  1277         NaN        1277
# 1272  107251528271309568       Hasmed  1277         NaN        1277
# 279   108284721867904137       Career  1274         NaN        1274
# 278   105388980252039870       Pleata  1257         NaN        1257
# 555   104287359934240404    Hans SamD  1256         NaN        1256
# 552   105516185566739968       Zothve  1256         NaN        1256
# 553    99566408350815597    Josedeodo  1256         NaN        1256
# 554    99566408537963625         Leza  1256         NaN        1256
# 1275  107251694749147163        Eddie  1255         NaN        1255
# 1276  107251533987191201         Taki  1255         NaN        1255
# 1273  109840461538739909        Qiang  1255         NaN        1255
# 342   108205130114574004     Pressure  1253         NaN        1253
# 334   110730240651882119        Thumb  1250         NaN        1250
# 944   100205572901889771          Paz  1248         NaN        1248
# 1191  108577048539332729     Mobility  1240         NaN        1240
# 1192  107577680385917533     Chookies  1240         NaN        1240
# 1363  109642948838393879         Orca  1240         NaN        1240
# 1189  108577048167390593     Denathor  1240         NaN        1240
# 947    99566408210057665          fNb  1237         NaN        1237
# 948   103743617977630492        Aegis  1237         NaN        1237
# 949    99566407784212776         Envy  1237         NaN        1237
# 950    99566407783597200        TitaN  1237         NaN        1237
# 951   108395422235497387      frostyy  1237         NaN        1237
# 1295  107251733033130549       Blazes  1235         NaN        1235
# 335   102483272156027229      deokdam  1235         NaN        1235
# 77    106302003665923326        SlowQ  1234         NaN        1234
# 1109   98926509821954141      Allorim  1232         NaN        1232
# 1130  105504937746753855        Sword  1232         NaN        1232
# 330    99566404535234175       Effort  1229         NaN        1229
# 1327   99566406443271739         Hana  1227         NaN        1227
# 1326   99566406483827119       Hanabi  1227         NaN        1227
# 1328   98767991808793901      Mission  1227         NaN        1227
# 1329  107705431471339985     Cryscata  1227         NaN        1227
# 382   104711227672883806       Heroic  1224         NaN        1224
# 384   103935407190789085   Nightmares  1224         NaN        1224
# 383   107444853138698643         Avra  1224         NaN        1224
# 380   108396643302446310          CPM  1224         NaN        1224
# 381   105589333565331737         Time  1224         NaN        1224
# 114   105530950989220354       Czypsy  1223         NaN        1223
# 111   105593133758273513       Savero  1223         NaN        1223
# 112   102181564347961738       Roison  1223         NaN        1223
# 113   103495716759395169      Neramin  1223         NaN        1223
# 110   102501215584239714        pr1me  1223         NaN        1223
# 1350  106548704012452390         Enso  1222         NaN        1222
# 1349  109642956482422883       Bruce   1222         NaN        1222
# 1348  104573207505851728        Minji  1222         NaN        1222
# 1347  106470433772093952        Lauva  1222         NaN        1222
# 1346  104573247991198730       Driver  1222         NaN        1222
# 903   105913339633194822        Srtty  1222         NaN        1222
# 506   103877785966088076    DenVoksne  1220         NaN        1220
# 505   107045034481599547        Vladi  1220         NaN        1220
# 507   103877921700775793       Twiizt  1220         NaN        1220
# 1308  107251381045668485       Hiro02  1220         NaN        1220
# 504   100205576934475691       Stefan  1220         NaN        1220
# 503   101389631540411777      Shikari  1220         NaN        1220
# 338   107492044257978794        Moham  1217         NaN        1217
# 300   107454956790371682         Duro  1217         NaN        1217
# 299   107839732971547014         Lure  1217         NaN        1217
# 298   105501858782308228       Roamer  1217         NaN        1217
# 296   107767810249714879      Rooster  1217         NaN        1217
# 945   100205572956493537         Once  1214         NaN        1214
# 905    98926509769517547        Armao  1214         NaN        1214
# 1407  102787200016286279     kamilius  1214         NaN        1214
# 1406  103536980547674776         Jezu  1214         NaN        1214
# 1403  100205576933154445       Ragner  1214         NaN        1214
# 1404  105503548109547493       Lyncas  1214         NaN        1214
# 1405  103935318111841563   toucouille  1214         NaN        1214
# 936   100304333966058512         Enty  1212         NaN        1212
# 935    99566404835201739        LokeN  1212         NaN        1212
# 934   102191958860550585         Jett  1212         NaN        1212
# 337   109619813466553788        DDoiV  1210         NaN        1210
# 319   108205131402932252        Jiwoo  1208         NaN        1208
# 644   100160799381721105   BioPanther  1205         NaN        1205
# 648   101383792831678607     Aladoric  1205         NaN        1205
# 647    99566406296347493         Raes  1205         NaN        1205
# 646   105709404500072628        Kisee  1205         NaN        1205
# 1170  107577677826081327     Messages  1203         NaN        1203
# 1168  105957589636391222      Dragoon  1203         NaN        1203
# 1169  109783448253640171        Kisno  1203         NaN        1203
# 1356   98767991764579452        Maple  1203         NaN        1203
# 339   107492059066783320        Saint  1202         NaN        1202
# 343   108567314915334762        Loki   1200         NaN        1200
# 1291  107251647709372417      Artemis  1196         NaN        1196
# 341   105501844568585626         DnDn  1196         NaN        1196
# 576   106276221575238438       SNAKER  1194         NaN        1194
# 574   100725844995692264      OnFleek  1194         NaN        1194
# 403   102787200009142846      Robocop  1194         NaN        1194
# 404   105830670848411185       Zicssi  1194         NaN        1194
# 405   105647947016264573      Jackies  1194         NaN        1194
# 406   105553614275532342      Khantos  1194         NaN        1194
# 407   102787200106595079        denyk  1194         NaN        1194
# 573   107492108437842420      Meaning  1194         NaN        1194
# 75    103536980522155001        Color  1193         NaN        1193
# 76    102147202400808332      Ryuzaki  1193         NaN        1193
# 78    105501834624360050          Ice  1193         NaN        1193
# 79    101388913283026351       kabbie  1193         NaN        1193
# 1166  107577676059296194      porsche  1193         NaN        1193
# 166   103890026402256038       Random  1191         NaN        1191
# 1293  107251726945594253       Coated  1191         NaN        1191
# 1296  107251561724960718       Shogun  1191         NaN        1191
# 854    99566406313688735        ry0ma  1189         NaN        1189
# 855    98767975937423972         k1ng  1189         NaN        1189
# 167   105532772496106458      Legolas  1189         NaN        1189
# 329   105320683858945274        Karis  1189         NaN        1189
# 856    98767991804151434     Smoothie  1189         NaN        1189
# 327   105501712240139757       Castle  1188         NaN        1188
# 1330  100164952147744283       Nestea  1187         NaN        1187
# 328   108205131295210982        Calix  1186         NaN        1186
# 1357  109691935302762726       Relhia  1184         NaN        1184
# 1358  107715200621484403          665  1184         NaN        1184
# 1359  107568562442006243         NuL1  1184         NaN        1184
# 1360  110548011912550056        Prage  1184         NaN        1184
# 1361  109823944385970403          Cha  1184         NaN        1184
# 333   108205130029559792       Lancer  1183         NaN        1183
# 1151  107577681865785858        Snow2  1182         NaN        1182
# 1150  109782993952426917     Levitate  1182         NaN        1182
# 1149  109709435411702734        Kachu  1182         NaN        1182
# 1148  107577681489871461        Leemo  1182         NaN        1182
# 1351  107568586413146262         Taco  1174         NaN        1174
# 1355  109691931003181723          IC8  1174         NaN        1174
# 1354  109691923934953698         Tide  1174         NaN        1174
# 1353  110548007844314658       Adiogs  1174         NaN        1174
# 1352  110548005438068785      Godtone  1174         NaN        1174
# 1288  110528442384858640       Sparda  1173         NaN        1173
# 1289  107251529370048921        BeanJ  1173         NaN        1173
# 1292  107251574398720447          Bie  1173         NaN        1173
# 1290  107255594187103787       Gloryy  1173         NaN        1173
# 575   102825747663199158         cody  1172         NaN        1172
# 165   107564399510583724       NoName  1171         NaN        1171
# 168   105672441522229073       Oscure  1171         NaN        1171
# 164   110350224593953686        Myrwn  1171         NaN        1171
# 859   107424988510472343       Spirax  1166         NaN        1166
# 860   108369186353082038        Massu  1166         NaN        1166
# 861   107424739201710992      Winsome  1166         NaN        1166
# 857   106857845200039597       Faisal  1166         NaN        1166
# 858   107424990007380124        Yuuji  1166         NaN        1166
# 285   109619811205255626         Frim  1166         NaN        1166
# 295   109549750903142546      Casting  1164         NaN        1164
# 561   105506922297942200     ACKERMAN  1163         NaN        1163
# 559   103619615096612421        Keine  1163         NaN        1163
# 558    99566408542840078        Solid  1163         NaN        1163
# 557   110451311575097696         ZOEN  1163         NaN        1163
# 1294  109828289393968653         Gury  1163         NaN        1163
# 1297  100205572921528567         Slay  1163         NaN        1163
# 560   105320665816491252         5kid  1163         NaN        1163
# 866   107577679924578125     Kim Down  1162         NaN        1162
# 862   106857825862018379      Bradley  1162         NaN        1162
# 863   102206361431680174          Mir  1162         NaN        1162
# 865    98926509788722983        Arrow  1162         NaN        1162
# 1337  104573231995499518         Holo  1159         NaN        1159
# 864   105957619949286329          APA  1156         NaN        1156
# 1414  105576833572820346  Pridestalkr  1156         NaN        1156
# 577   103658555207094087     Shu Hari  1153         NaN        1153
# 336   110660139298018837       Kangin  1153         NaN        1153
# 579    99566408310768239   WARANGELUS  1149         NaN        1149
# 513   110428377116620637       Seneca  1148         NaN        1148
# 511   105593236438009434         OMON  1148         NaN        1148
# 510   105519810846425134   Indecision  1148         NaN        1148
# 509   105530965398630857       Kackos  1148         NaN        1148
# 686   102787200033260130        Kektz  1147         NaN        1147
# 690   105531042891555696       Wojtus  1147         NaN        1147
# 1408  101389749294612370          JNX  1147         NaN        1147
# 1409  101389737451765151        Lurox  1147         NaN        1147
# 687   108404241877151289        Mafro  1147         NaN        1147
# 688   105553695849396121         Diva  1147         NaN        1147
# 689   107603178888651345    Shy Carry  1147         NaN        1147
# 1411  101389760979975607       Keduii  1147         NaN        1147
# 1412  102181658605626513        Prime  1147         NaN        1147
# 1410   99294153745917471      FEBIVEN  1147         NaN        1147
# 124   103889920053283022   Th3Antonio  1146         NaN        1146
# 125    99322214660829968        Xerxe  1146         NaN        1146
# 126   103478281310155270        Decay  1146         NaN        1146
# 127   103889952158815326       Attila  1146         NaN        1146
# 128   103935363652349248     whiteinn  1146         NaN        1146
# 870   107577674957373878        Minui  1146         NaN        1146
# 869   107577675179868602       shochi  1146         NaN        1146
# 868   107569576434463367        Perry  1146         NaN        1146
# 867   106547199482728931       Philip  1146         NaN        1146
# 981   109518818558571904          Nia  1146         NaN        1146
# 980   107560357748334767    NinjaKiwi  1146         NaN        1146
# 979   103478281346265622     NOsFerus  1146         NaN        1146
# 978    99566407784942056        Yampi  1146         NaN        1146
# 977   108443041194004491          Zzk  1146         NaN        1146
# 871    99322404269006062         JayJ  1146         NaN        1146
# 1364  106470311122977099        Felia  1143         NaN        1143
# 999   105397130782159175        SCARY  1143         NaN        1143
# 1419   99322214580759173    Cabochard  1142         NaN        1142
# 90    107065250314387793         Zora  1142         NaN        1142
# 1423   99322214657019865     Targamas  1142         NaN        1142
# 1422  109461265532592848      Caliste  1142         NaN        1142
# 1421  101389808357457357        SAKEN  1142         NaN        1142
# 1420  102787200080511709      Cinkrof  1142         NaN        1142
# 1171  107577679471034957        sajed  1142         NaN        1142
# 1416  102747101536135974      Trigger  1141         NaN        1141
# 1415  102181670376678547     Czekolad  1141         NaN        1141
# 1417  107450769953280129    Veignorem  1141         NaN        1141
# 1413  105501829364113001      Howling  1141         NaN        1141
# 1274  101185557155755861     Artifact  1141         NaN        1141
# 520   104738075494511822        Guubi  1140         NaN        1140
# 985   105397249991107623       Brance  1139         NaN        1139
# 986    99566408211536727         JoJo  1139         NaN        1139
# 982    99566407758231326          Tay  1139         NaN        1139
# 983   105397234464043531      Disamis  1139         NaN        1139
# 984   100131567589299245         hauz  1139         NaN        1139
# 94    105589296803730470       KroMAX  1138         NaN        1138
# 93    104727114888994943        GotzY  1138         NaN        1138
# 92    107599402353022334         Ribu  1138         NaN        1138
# 91    110378665590552147     nicolayi  1138         NaN        1138
# 1185  106857955107567927        rovex  1137         NaN        1137
# 332   110344206284416878         Nice  1137         NaN        1137
# 562   107581373077374269          pan  1130         NaN        1130
# 564   109656280616610105         Kaze  1130         NaN        1130
# 565   103727753345856483      Gavotto  1130         NaN        1130
# 566    99566404541748447        Jelly  1130         NaN        1130
# 902   107577678085079603     Duoking1  1130         NaN        1130
# 609   103935344200338383        Julbu  1129         NaN        1129
# 611   108404607430446490      FlickeR  1129         NaN        1129
# 612   105526656218466158      KINGPIN  1129         NaN        1129
# 608   105526650034947922     Zhergoth  1129         NaN        1129
# 610   107217815918221367       Erolle  1129         NaN        1129
# 287   109625890321208220       Ivory   1127         NaN        1127
# 922   101388913286565299         TaNa  1125         NaN        1125
# 925   105576902117578145         Ssol  1125         NaN        1125
# 1282   98767975954252935      Palette  1125         NaN        1125
# 923   101796977262248072   hachamecha  1125         NaN        1125
# 924   101796953887103159        Recap  1125         NaN        1125
# 1345  106470368396369858        Smerv  1123         NaN        1123
# 962   103743600803050303        Hidan  1121         NaN        1121
# 290   107492099069012459         Zest  1121         NaN        1121
# 563   101388913288334773        Seize  1121         NaN        1121
# 1382  107828128913848160       Toasty  1121         NaN        1121
# 1315  109828491272922055          Emo  1121         NaN        1121
# 159   107462755349678558        Stend  1121         NaN        1121
# 158   105553696718837337         Jopa  1121         NaN        1121
# 157   105532803085558758         Baca  1121         NaN        1121
# 156   103461966929364884        Koldo  1121         NaN        1121
# 155   102808840667875469     Sinmivak  1121         NaN        1121
# 454   101389713985551761      Woolite  1120         NaN        1120
# 451   108362989061999316     Banderas  1120         NaN        1120
# 452   104738020689179820      Bruness  1120         NaN        1120
# 453   105589292050372795        ESCIK  1120         NaN        1120
# 937   105581684606195509        Dicey  1120         NaN        1120
# 455   102787200023364184    Bananitoo  1120         NaN        1120
# 288   108205132580169451        Enosh  1119         NaN        1119
# 943   106803906751189833  Shakespeare  1118         NaN        1118
# 1299  107251649649434629        Phuc1  1118         NaN        1118
# 169   105537497177165376      Viketox  1118         NaN        1118
# 121   108316930489533786     ShadowUS  1117         NaN        1117
# 651   105747868966238958       Whynot  1116         NaN        1116
# 654   110456595734087817         Akia  1116         NaN        1116
# 653   107635218337333813       leemas  1116         NaN        1116
# 652   109675673940491206      Daystar  1116         NaN        1116
# 446   105515354716470535       EYLIPH  1116         NaN        1116
# 447   102418332506104195       SPOOKY  1116         NaN        1116
# 448   107614656149746484       HAWHAW  1116         NaN        1116
# 650   103524181318400020        Lived  1116         NaN        1116
# 449   102787200035816046  GOLDENTO4ST  1116         NaN        1116
# 450   105554098262562524        iLEVI  1116         NaN        1116
# 1424  107570755067676153       Venour  1115         NaN        1115
# 1426  105320657222755563         Mask  1115         NaN        1115
# 1427  105503878796929117      Fun K3y  1115         NaN        1115
# 1425  104266798781419767          CaD  1115         NaN        1115
# 1428  103963504851030950       Lekcyc  1115         NaN        1115
# 314   109523135356383683       Diable  1114         NaN        1114
# 516   109701698226626452      Ragnarr  1114         NaN        1114
# 315   109523135464568456        PlanB  1114         NaN        1114
# 580   107582134651766734         Hika  1114         NaN        1114
# 740   100205573453110710        Asper  1114         NaN        1114
# 737    99566406042760186       Mojito  1114         NaN        1114
# 312   108205131858552538     Vincenzo  1114         NaN        1114
# 739   101422616386005719        Kaori  1114         NaN        1114
# 311   108205131563823136      DDahyuk  1114         NaN        1114
# 736   101422616412154641   StarScreen  1114         NaN        1114
# 738    99566404562781815        Tempt  1114         NaN        1114
# 313   109523134874809981         Guti  1114         NaN        1114
# 972   100131733430915231        Guigo  1113         NaN        1113
# 973    99566405933319527        Grell  1113         NaN        1113
# 974   103743619023893329     Grevthar  1113         NaN        1113
# 975   103743620262608671        Trigo  1113         NaN        1113
# 976   100205576297917527       Damage  1113         NaN        1113
# 539   110524169283193270         Cast  1112         NaN        1112
# 540   103877889738969784  FlayStation  1112         NaN        1112
# 1137  110536140884380252       Frost1  1111         NaN        1111
# 567   107582138342164469        KinGi  1109         NaN        1109
# 1184  107828217272563683   SiddyWiddy  1109         NaN        1109
# 326   109523120092920046        Guwon  1109         NaN        1109
# 1183  108604965748174033    Lawrencee  1109         NaN        1109
# 286   107492130895812257       Raptor  1109         NaN        1109
# 1310  108242852190151592     playcool  1109         NaN        1109
# 1074  109696321402233574         san1  1108         NaN        1108
# 1072   99566405676244251      Elramir  1108         NaN        1108
# 1071  102174664449879465       Juuzou  1108         NaN        1108
# 876   107577674683630078      donbray  1108         NaN        1108
# 72    107156535965754342         many  1107         NaN        1107
# 73    105655995799330206         svns  1107         NaN        1107
# 71    109539786056381355         adi1  1107         NaN        1107
# 70    109704758065825536       Matixx  1107         NaN        1107
# 1096  109696597022202866       Cipher  1107         NaN        1107
# 74    106302540732814072   minemaciek  1107         NaN        1107
# 1075  109696509178731479       Mishal  1107         NaN        1107
# 904   101383792849832093        Haeri  1106         NaN        1106
# 629   109675752512061621        sHAKa  1104         NaN        1104
# 822   105548731617719496      Rhilech  1104         NaN        1104
# 821   109705412728201213      Empyros  1104         NaN        1104
# 823   103963733877026827        XoNix  1104         NaN        1104
# 1001  105541438961192885        Samkz  1104         NaN        1104
# 824   105548605376090785     Aetinoth  1104         NaN        1104
# 825   107564428297402857         Nash  1104         NaN        1104
# 968   105397190018458463         Goot  1103         NaN        1103
# 971   107559356925533344          zay  1103         NaN        1103
# 970   108613483446049530          Ayu  1103         NaN        1103
# 969   103478281329357326        Tutsz  1103         NaN        1103
# 967   105397188336529754        Betao  1103         NaN        1103
# 538   108403325203192138       Moxokx  1103         NaN        1103
# 1397  108369185316532444         Plux  1103         NaN        1103
# 993    98767975928947066        Trick  1103         NaN        1103
# 495   105519985314726097       ERIXEN  1101         NaN        1101
# 671   105709428644866635         Apii  1101         NaN        1101
# 1172  109783332353900398        Chaye  1100         NaN        1100
# 153   100238780548957608       Deadly  1099         NaN        1099
# 152   105592952445950837      Sajator  1099         NaN        1099
# 151    98767975905644361      Maxlore  1099         NaN        1099
# 150    99322214668103078  WhiteKnight  1099         NaN        1099
# 154   102808559137385915        Efias  1099         NaN        1099
# 578    99566405793083799     Straight  1098         NaN        1098
# 512   110428375437150775         Hid0  1098         NaN        1098
# 933   103734698412635497        Nesty  1098         NaN        1098
# 675   110456581491929979     Hexflash  1098         NaN        1098
# 324   108205129774185945        Smash  1097         NaN        1097
# 1280  102300322396525713         Dia1  1096         NaN        1096
# 926   101383792848062619     Corporal  1096         NaN        1096
# 117   107897279509247244        Kubon  1096         NaN        1096
# 1281  107642470610994763      Vinboiz  1096         NaN        1096
# 1279  102848965907008705          DNK  1096         NaN        1096
# 1278  107251383938441076         Nper  1096         NaN        1096
# 109   107583006037594408         M0NK  1096         NaN        1096
# 963   106393510086922506        enel1  1095         NaN        1095
# 306   106288130582997353      IlllIma  1094         NaN        1094
# 668    98767975963407611    Shernfire  1093         NaN        1093
# 667    98767975960315466      Chippys  1093         NaN        1093
# 669   109675698771867688       DONGGY  1093         NaN        1093
# 670   103643243250697054       Violet  1093         NaN        1093
# 674   107634941727734818    foreigner  1092         NaN        1092
# 1000  109519064896337328      Momochi  1091         NaN        1091
# 521   101422616400870677       Wendel  1090         NaN        1090
# 519   104738071249024202     Knighter  1090         NaN        1090
# 518   101389608248295276        Taxer  1090         NaN        1090
# 517   103877885177694021        Nille  1090         NaN        1090
# 691   102147202389024706       KLOWNY  1088         NaN        1088
# 693   105521300963305788        Peppe  1088         NaN        1088
# 694   105521508319865335    Vaynedeta  1088         NaN        1088
# 875   108363489514100950         Lens  1088         NaN        1088
# 874   101383793878119688       Soligo  1088         NaN        1088
# 873   105504917038491916         Keel  1088         NaN        1088
# 872   107577677538574806       Zamudo  1088         NaN        1088
# 695   103889983720130825    TasteLess  1088         NaN        1088
# 692   106371041332804856        VELJA  1088         NaN        1088
# 289   108284723448093299        Pollu  1087         NaN        1087
# 912    99871352196477603       Hoglet  1086         NaN        1086
# 914   105501810581233217     Valkyrie  1086         NaN        1086
# 1385  108373031065427229        V1tal  1086         NaN        1086
# 915   103734705460272719          Ino  1086         NaN        1086
# 913   105576988443760133     Megumiin  1086         NaN        1086
# 1418  109501429543145709  Pridestalke  1085         NaN        1085
# 108   108353503453906607      Syzyfek  1085         NaN        1085
# 293   109549753100907815        Carfe  1085         NaN        1085
# 294   107492067202132417        Lospa  1085         NaN        1085
# 291   107492072900515430       Winner  1085         NaN        1085
# 292   105501729817539861      Ophelia  1085         NaN        1085
# 175   105553694947530323      xeonerr  1084         NaN        1084
# 1077   99566406317824602         Pabu  1084         NaN        1084
# 515   110490655803091760          Fai  1084         NaN        1084
# 589   105526630132932827       Mikkel  1084         NaN        1084
# 147   101422616391248613       Zwyroo  1082         NaN        1082
# 148   105537493709655597  Jackspektra  1082         NaN        1082
# 141   105589352108344000         Mart  1082         NaN        1082
# 123   107599450838783910      Grypcio  1082         NaN        1082
# 325   105320652477753436         Baut  1082         NaN        1082
# 145   102787199997762691          iBo  1082         NaN        1082
# 146   103935317076176149     bluerzor  1082         NaN        1082
# 322   107444134161788861       Forest  1082         NaN        1082
# 1298  102849319862407551      Yoshino  1082         NaN        1082
# 321   108205129336536529          Dal  1082         NaN        1082
# 660   104573177846147434       Yursan  1082         NaN        1082
# 1302  102849319864045953        Hieu3  1082         NaN        1082
# 149   106302528293858788       marlon  1082         NaN        1082
# 659   105714267311249927       Chayon  1080         NaN        1080
# 658   107657790493529410      DaJeung  1080         NaN        1080
# 657   102206337830843087        Souli  1080         NaN        1080
# 656   101799086969700514        Thien  1080         NaN        1080
# ...
# 732    99566404827686445    Chieftain   958         NaN         958
# 757   110534542285887216    Taegyeong   957         NaN         957
# 758   104251861472500857     osman123   957         NaN         957
# 759   110534540983961624      Nakyung   957         NaN         957
# 760   105548640573510364         Ruep   957         NaN         957
# 761   106314065943471432      Paixdia   957         NaN         957
# 720   105520720212515992       Sahira   957         NaN         957
# 1105  109696463795912565       Mimic1   957         NaN         957
# 1135  109783494492192736     Kurulean   957         NaN         957
# 1134  107577679867396578       sahori   957         NaN         957
# 1132  107577679733344073    duong pro   957         NaN         957
# 1131  109783499814022325   BoilTheOil   957         NaN         957
# 470   107603213805511339       Lauxio   956         NaN         956
# 838   107105623720382721  Dream Maker   955         NaN         955
# 395   106528193904857188     Sinistro   955         NaN         955
# 394   104727109824541639         F4rg   955         NaN         955
# 840   103877753472979523          S1D   955         NaN         955
# 839   105519570521259934        Kehvo   955         NaN         955
# 989   101383793127111259     Krastyel   955         NaN         955
# 837   109081868915969609      FaithXD   955         NaN         955
# 991    98767975947296513      RedBert   955         NaN         955
# 987   103537145723534552       Lonely   955         NaN         955
# 990   104410793439045393        RAV3N   955         NaN         955
# 836   102808745119787330       WeiZoR   955         NaN         955
# 365   106312605281690369     Campello   954         NaN         954
# 748   104251866878130069        Rames   954         NaN         954
# 626   110650593646695855         Choi   954         NaN         954
# 490   107186942128466050       REVENG   954         NaN         954
# 763   107605339681186357         chef   953         NaN         953
# 624   110454460337978890    TheRealMJ   953         NaN         953
# 676   106314064472890339       Aytekn   953         NaN         953
# 680    99566406051575530     Farfetch   953         NaN         953
# 766   100174488533148944          Pbd   953         NaN         953
# 764   101422910059309862    stillnumb   953         NaN         953
# 765   107601504476977337      Sangchu   953         NaN         953
# 762   103495716693930864        HiRit   953         NaN         953
# 1126  107577677304317723        Saico   953         NaN         953
# 310   105548653898118261        Andil   952         NaN         952
# 1398  106224537706159853        Hyper   952         NaN         952
# 463   105521648113779564        Lotus   952         NaN         952
# 464   104738172861178386         ORRE   952         NaN         952
# 465   105548606962065935        Joexy   952         NaN         952
# 1115  110535911000262575           K2   951         NaN         951
# 1065  109721314351572557        Murph   950         NaN         950
# 366   107105629505887212          rnz   950         NaN         950
# 594   110467125405233208       Jormag   950         NaN         950
# 714   105547923973923133        Kanna   949         NaN         949
# 1069  105501853255458466        Yusin   949         NaN         949
# 1068  110489749932282048        Shark   949         NaN         949
# 1067  107649288780615180     Koussay3   949         NaN         949
# 1066  109721322428556881         Dean   949         NaN         949
# 717   109697735763092500     Gorilla1   949         NaN         949
# 716   109697641061679165          mdb   949         NaN         949
# 713   109907677402992796  Fornoreason   949         NaN         949
# 1176  109800032657915058          Zev   949         NaN         949
# 715   105576916849153487       Sintax   949         NaN         949
# 849    99124844346233375    Zergsting   949         NaN         949
# 1025  101383793082615993        ST3PZ   947         NaN         947
# 900   105504918290295055        Spawn   947         NaN         947
# 901   105504929492494649          Nxi   947         NaN         947
# 898   105504934624551000    RoseThorn   947         NaN         947
# 1024  107560281476330464       Leleko   947         NaN         947
# 1023  103478281341350420        Sting   947         NaN         947
# 1022  103478281338008082        Tyrin   947         NaN         947
# 899   107828129079238914         Onat   947         NaN         947
# 348   110461616052667662      Lyrokun   946         NaN         946
# 345   106302915507613423       Jackie   946         NaN         946
# 347   107609997924362264      Qu4rtzo   946         NaN         946
# 346   105589326261016816  RapMonsters   946         NaN         946
# 344   110461613173984538       Shieda   946         NaN         946
# 617   110454464878883238        Emiel   946         NaN         946
# 385   109710759101933287     Unversed   945         NaN         945
# 921   110536783764146522     kentakki   945         NaN         945
# 476   105751319523372184      Sangrod   945         NaN         945
# 477   105521267488578852  SneakyLemon   945         NaN         945
# 478   107450793732493452       Freazy   945         NaN         945
# 1177  110535890767022535     picapica   945         NaN         945
# 479   107621049304382073        Chova   945         NaN         945
# 1175  110535883175254401        Reppy   945         NaN         945
# 1174  110535880045031281       deamon   945         NaN         945
# 1173  107577680457975637         Aizo   945         NaN         945
# 1163  110535828194822891    Debounair   944         NaN         944
# 1153  110536452245981966     Excelsis   944         NaN         944
# 1161  108359201080216019    Livatious   944         NaN         944
# 1095  109696326756459242    B Butcher   944         NaN         944
# 1164  109783492667538764   Enthralled   944         NaN         944
# 1165  110535834235603720      Cryogen   944         NaN         944
# 1094  110489865842850893        Nawaf   944         NaN         944
# 938   105785814323282335     Washidai   943         NaN         943
# 939   105576910026266044          HRK   943         NaN         943
# 940    99566406029648577         Acee   943         NaN         943
# 942   105752114670266447        hetel   943         NaN         943
# 941   106583550519921617    dresscode   943         NaN         943
# 1138  107577678374651690         Doxa   943         NaN         943
# 1059  109696472020474825   Lickmyheal   942         NaN         942
# 388   107840729655290333      Sofista   941         NaN         941
# 719   107065248659785937    Lagolinas   939         NaN         939
# 751   104251869095189646        Carry   939         NaN         939
# 747   107492129389636107       Soboro   939         NaN         939
# 749   100205576892779480       Milica   939         NaN         939
# 750   107492188426262204        Gamin   939         NaN         939
# 844   106306514729595126        xDrop   938         NaN         938
# 704   110468634669232825      Becomin   937         NaN         937
# 1124  108369186541738788       Geiger   936         NaN         936
# 613   110454416579506544         W1ND   936         NaN         936
# 1125  110536055449776091     Nemesis9   936         NaN         936
# 1127  110536062618191877       Pluto1   936         NaN         936
# 614   107648239342422928      TR1NKET   935         NaN         935
# 471   107065256938832257        DANKI   933         NaN         933
# 473   107633881734248402          QKI   933         NaN         933
# 475   107768042767707404       Dargod   933         NaN         933
# 466   108448765407357094       Youca1   931         NaN         931
# 467   106425061853706320      N3znamy   931         NaN         931
# 700   109696850540756983         Iheb   931         NaN         931
# 699   109697774254218451    Komandata   930         NaN         930
# 1017  110434101013364855       Baldan   928         NaN         928
# 810   108370564349293151         Taba   928         NaN         928
# 1021  105397194580419452         Kick   928         NaN         928
# 1020  109518621083964549       Kojima   928         NaN         928
# 1018  107559262560546832      Ancrath   928         NaN         928
# 1019  109518619333850417       Picknn   928         NaN         928
# 807   110442614728546763    TheCheeng   927         NaN         927
# 480   104738067226752196    StenBosse   927         NaN         927
# 1049  107559633217576287         Yuki   926         NaN         926
# 469   105521213251945010         Ralf   926         NaN         926
# 468   109517025487758872      Artoria   926         NaN         926
# 745    99566405672409608     Absolute   922         NaN         922
# 741   104251865849200240          NuQ   922         NaN         922
# 742   101422616390331107       Kireas   922         NaN         922
# 744   104251402967330496     ANDARIEL   922         NaN         922
# 743    99566405677872785        KSAEZ   922         NaN         922
# 390   109710870238536405      TiaguuZ   921         NaN         921
# 1026  106276191141062603        Telas   921         NaN         921
# 430   105593168057325647      Defflok   920         NaN         920
# 601   110467101022652871        Space   920         NaN         920
# 445    99591620723806690       Only35   920         NaN         920
# 428   105593139764222998       Kulvas   920         NaN         920
# 443   105521714704604859        J0J0C   920         NaN         920
# 429   108353501983434860        Kokos   920         NaN         920
# 602   110467102847568333         Baul   920         NaN         920
# 442   106250634907345354      Carnage   920         NaN         920
# 600   109749151366449336         Aisu   920         NaN         920
# 432   105530925544497872       Meleks   920         NaN         920
# 599   110467097878412456        Niton   920         NaN         920
# 598   110467096336085013   Dusseldrop   920         NaN         920
# 431   110473357277149314     Hiro Hai   920         NaN         920
# 441   105531045249475446       Ariana   919         NaN         919
# 1162   99322380962940029       Kitzuo   918         NaN         918
# 369   110516286276858435        Bwezc   917         NaN         917
# 444   107065253176002809     Unkn0wn5   916         NaN         916
# 705   109777166200522611       taetsu   916         NaN         916
# 1133  108359201586419546    XiaoDanny   915         NaN         915
# 707   107598996496766408        Piggy   914         NaN         914
# 703   107603146535494194       v1SaG3   914         NaN         914
# 706   109697650160886777        Simbz   914         NaN         914
# 1011  100205576296653806        Anyyy   905         NaN         905
# 597   105526530318262327      Mahonix   904         NaN         904
# 595   107128033996363478  jbdutchowns   904         NaN         904
# 596   105526631082340033       Slyv3r   904         NaN         904
# 593   109630251485149741       MaiYuk   904         NaN         904
# 1246  110536823096052962       suzuki   902         NaN         902
# 1247  110536825647942004         Tele   902         NaN         902
# 1245  110536821680082132         Tima   902         NaN         902
# 1244  110536819719244763        Perle   902         NaN         902
# 1248  110536826999049446       Odessa   902         NaN         902
# 1091  104727029057544258         Bako   901         NaN         901
# 1058  109696925995965022      Jalleba   901         NaN         901
# 1056  110490053943753928         Kudy   901         NaN         901
# 1055  105519983884478282     Kerberos   901         NaN         901
# 1093  109721399266584404         Meza   901         NaN         901
# 1057  106313027403543673       wicked   901         NaN         901
# 811   105537001537910115      Paradox   899         NaN         899
# 809   106306526029050111        FENZ1   899         NaN         899
# 808   106302941100973218      Gaboesh   899         NaN         899
# 697   105521713660013187       Hatred   899         NaN         899
# 1027  100131567588515623       Sephis   892         NaN         892
# 843   107648247747839403     Skaterot   891         NaN         891
# 841   107688960045460307          kPr   891         NaN         891
# 842   106544654239535161          XnS   891         NaN         891
# 845   107610020225673259         Joao   891         NaN         891
# 424   105532806069062516   Shyelander   890         NaN         890
# 1250  104253137978020060       Yunika   889         NaN         889
# 1251  107618427663806057       Kakkun   889         NaN         889
# 1252  106645154191921942        Deant   889         NaN         889
# 1249  106304305078654334         Momo   889         NaN         889
# 1047  105758879937719082         Miss   887         NaN         887
# 425   106306512827785017      Scuffed   884         NaN         884
# 423   109777192967695724       Bobsik   884         NaN         884
# 1033  103743605928031045       Eradan   884         NaN         884
# 426   106382521225691600     Promise0   884         NaN         884
# 427   106425066185676210        Marco   884         NaN         884
# 1053  109518716685978765        Manel   882         NaN         882
# 1003  106279668107187055       Hugato   880         NaN         880
# 1005  102135522496703527       Vahvel   880         NaN         880
# 1050  110434599226250000        Alles   880         NaN         880
# 1048  109519428307200356       Beta32   880         NaN         880
# 1002  107560059495150409        Makes   880         NaN         880
# 1004  110434691941186965         Sant   880         NaN         880
# 1054  110434225307697321         xyno   878         NaN         878
# 1007  110434822594728434         doom   877         NaN         877
# 368   110461599669213327         Zen    875         NaN         875
# 1028  109518712216515937          Gru   873         NaN         873
# 1052  109518814253943969        Paclo   872         NaN         872
# 696   106371066008890473        Boras   869         NaN         869
# 1032  110434250535850063       Shoiti   869         NaN         869
# 1016  109519059241407699      Ryanzin   868         NaN         868
# 1034  108494063372887027         Tatu   856         NaN         856
# 1035  102135534311497703       Blacky   856         NaN         856
# 1036  101383793149917827         Juzo   856         NaN         856
# 1037  109518816550791300         Look   856         NaN         856
# 1029  107559327426244686       StineR   851         NaN         851
# 1030  107559338252333149         Fuuu   851         NaN         851
# 1031  109518714719221538         yazi   851         NaN         851
# 1009  108395451349202875    Morttheus   846         NaN         846
# 1010  103743593842085398      scamber   846         NaN         846
# 1008  103980682928812378      Aithusa   846         NaN         846
# 1258  110541201911314014      Karaage   838         NaN         838
# 1259  110541203636707305       Racon7   838         NaN         838
# 1260  110541205994705138      Jericho   838         NaN         838
# 1261  110541207920349533         fyrk   838         NaN         838
# 1006  107559597273805278       Soweto   835         NaN         835
# 1042  106279008706914426         Mido   805         NaN         805
# 1040  108576894549726185        neyzz   805         NaN         805
# 1041  107560148944019348         Celo   805         NaN         805
# 1038  110641242832915320     JotaEmeZ   800         NaN         800
# 1257  110541320575815956         besu   793         NaN         793
# 1256  108611831454049354      Sunleaf   793         NaN         793
# 1255  110541319032037422       Yosida   793         NaN         793
# 1254  107635689777265916        Tatsu   793         NaN         793
# 1253  110541316136788001        Ussii   793         NaN         793
# 1039  109519179723052282        CrjaY   781         NaN         781
# 1240  109682853490267977   96NKtaityo   747         NaN         747
# 1242  110536796541677893        1buki   747         NaN         747
# 1243  110540264433553284         evol   747         NaN         747
# 1241  110536777090396446      HALdesu   747         NaN         747

# %%
teams.loc[teams['team_id'] == "99566404850008779"]
# Out:
#                 team_id                name acronym         slug
# 1398  99566404850008779  Suzhou LNG Esports     LNG  lng-esports

# %%
teams.sort_values(by =['team_id'], inplace =True)105511293284046174

# %%
players.loc[players['player_id'] == "110547957837987327"]
# Out:
#                player_id handle first_name last_name       home_team_id
# 4491  110547957837987327     0N     WENJUN       LUO  99566404853854212

# %%
players.loc[players['handle'] == "ON"]
# Out:
#                player_id handle first_name last_name home_team_id
# 5156  105516578130811296     ON    Wen-Jun       Luo         None

# %%
teams.loc[teams['team_id'] == "102235771678061291"]
# Out:
#                 team_id                         name acronym              slug
# 592  102235771678061291  DenizBank İstanbul Wildcats      IW  fastpay-wildcats

# %%
mapping_data.loc[mapping_data['esportsGameId'] == "108998961199895793"]['participantMapping.3'].item()
# Out:
# '98767991747728851'

# %%
mapping_data.loc[mapping_data['esportsGameId'] == "110428848767941212"]
# Out:
#            esportsGameId platformGameId    teamMapping.200    teamMapping.100  \
# 3935  110428848767941212   LPL_A:343741  99566404853854212  99566404850008779
#
#      participantMapping.3 participantMapping.5 participantMapping.10  \
# 3935    98767975951139628   103817065229388803    110547957837987327
#
#      participantMapping.2 participantMapping.1 participantMapping.9  \
# 3935    99871276342823057   108477153941144313   106368692529261498
#
#      participantMapping.7 participantMapping.8 participantMapping.6  \
# 3935   105516152837078491    99566404798393925   103478281356330346
#
#      participantMapping.4
# 3935   101388912814247335

# %%
players['ELO'] = np.nan

# %%
new_leagues
# Out:
#                     id                              slug   ELO
# 0    98767991299243165                               lcs  1300
# 1   109511549831443335  north_american_challenger_league  1100
# 2   109518549825754242        lcs_challengers_qualifiers  1000
# 3   107898214974993351              college_championship  1000
# 4    98767991332355509                      cblol-brazil  1100
# 5    98767991310872058                               lck  1600
# 6    98767991355908944                               lcl  1100
# 7   105709090213554609                               lco  1100
# 8    98767991302996019                               lec  1400
# 9    98767991349978712                         ljl-japan  1100
# 10  101382741235120470                               lla  1100
# 11   98767991314006698                               lpl  1600
# 12  104366947889790212                               pcs  1200
# 13   98767991343597634          turkiye-sampiyonluk-ligi  1000
# 14  107213827295848783                               vcs  1100
# 15   98767991325878492                               msi  1500
# 16   98767975604431411                            worlds  1500
# 17   98767991295297326                          all-star  1500
# 18  100695891328981122                      emea_masters  1100
# 19  105266103462388553                               lfl  1100
# 20  105266098308571975                               nlc  1100
# 21  107407335299756365                      elite_series  1000
# 22  105266101075764040                   liga_portuguesa  1000
# 23  105266094998946936                      pg_nationals  1000
# 24  105266088231437431                         ultraliga  1100
# 25  105266074488398661                         superliga  1100
# 26  105266091639104326                       primeleague  1100
# 27  105266106309666619                  hitpoint_masters  1000
# 28  105266111679554379             esports_balkan_league  1000
# 29  105266108767593290                     greek_legends  1000
# 30  109545772895506419                    arabian_league  1000
# 31  108203770023880322                       lck_academy  1000
# 32  106827757669296909                       ljl_academy   900
# 33   98767991335774713            lck_challengers_league  1200
# 34  105549980953490846                     cblol_academy   900
# 35  110371976858004491             north_regional_league   900
# 36  110372322609949919             south_regional_league   900

# %%
if '103536921518408674' not in ELO_players.values :
    ELO_players = start_elo('103536921518408674','98767991302996019',ELO_players)
playerss = ['103536921518408674','103536921518408674','103536921518408674','103536921518408674','103536921518408674']

# %%
ELO_players
# Out:
#                    id handle   ELO
# 0  103536921518408674  LIMIT  1450
